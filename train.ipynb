# %%
from google.colab import files, drive
# !mkdir -p drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### step 1 : import all relevant open library

import csv
import sys
import re
import logging
import os,re
import pickle
import sys,os,time
from typing import Union

import numpy as np

import math
from itertools import chain
from collections import Counter


import json
import random

  
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

# %%
## step: 1 check cuda version
print(torch.__version__)
# Out:
# 1.8.1+cu101

# %%
### step 2：define relevant folders

## step 2.1: define master folder
master_holder='/content/gdrive/My Drive/ETNET/ipo_pdf/ner'#

# %%
## step 2.2: define data folder and train/test data file
data_folder=os.path.join(master_holder,'data')
train_data=os.path.join(data_folder,'revised_full.txt')
test_data=os.path.join(data_folder,'test.txt')

# %%
## step 2.3: define model folder, model file and other model related files

model_folder=os.path.join(master_holder,'model3')

sent_vocab_file=os.path.join(model_folder,'sent_vocab.json')
tag_vocab_file=os.path.join(model_folder,'tag_vocab.json')


model_file=os.path.join(model_folder,'model.pth')
optimizer_file=os.path.join(model_folder,'optimizer.pth')

# %%
### step 3 : define loading data function

### step 3.1: define function to read train/test data files
def read_corpus(filepath):

    sentences, tags = [], []
    sent, tag = ['<START>'], ['<START>']
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
                line = line.split('\t')
                if len(line)==2:
                 # print(line[0],line[1])
                  sent.append(line[0].strip())
                  tag.append(line[1].strip())

                else:
                    if len(sent) > 1:
                     # print(sent,tag)
                      sentences.append(sent + ['<END>'])
                      tags.append(tag + ['<END>'])
                      sent, tag = ['<START>'], ['<START>']
    return sentences, tags

# %%
### step 3.2: define dictionary to contain word and word indice
def words2indices(origin, vocab):
    if isinstance(origin[0], list):
        result = [[vocab[w] for w in sent] for sent in origin]
    else:
        result = [vocab[w] for w in origin]
    return result

def indices2words(origin, vocab):
    if isinstance(origin[0], list):
        result = [[vocab.id2word(w) for w in sent] for sent in origin]
    else:
        result = [vocab.id2word(w) for w in origin]
    return result

# %%
### step 3.3: convert training data, word and word indice to train/dev datasset

def generate_train_dev_dataset(filepath, sent_vocab, tag_vocab, train_proportion=0.8):
  
    sentences, tags = read_corpus(filepath)
    sentences = words2indices(sentences, sent_vocab)
    tags = words2indices(tags, tag_vocab)
    data = list(zip(sentences, tags))
    random.shuffle(data)
    n_train = int(len(data) * train_proportion)
    train_data, dev_data = data[: n_train], data[n_train:]
    return train_data, dev_data

# %%
### step 4: define model training related function

### step 4.1: step define supplementary function to pad data and batch training

def pad(data, padded_token, device):
    lengths = [len(sent) for sent in data]
    max_len = lengths[0]
    padded_data = []
    for s in data:
        padded_data.append(s + [padded_token] * (max_len - len(s)))
    return torch.tensor(padded_data, device=device), lengths


def batch_iter(data, batch_size=32, shuffle=True):
   
    data_size = len(data)
    indices = list(range(data_size))
    if shuffle:
        random.shuffle(indices)
    batch_num = (data_size + batch_size - 1) // batch_size
    for i in range(batch_num):
        batch = [data[idx] for idx in indices[i * batch_size: (i + 1) * batch_size]]
        batch = sorted(batch, key=lambda x: len(x[0]), reverse=True)
        sentences = [x[0] for x in batch]
        tags = [x[1] for x in batch]
        yield sentences, tags

def print_var(**kwargs):
    for k, v in kwargs.items():
        print(k, v)

# %%
### step 3.4: define Vocab class to words and word indice

class Vocab:
    def __init__(self, word2id, id2word):
        self.UNK = '<UNK>'
        self.PAD = '<PAD>'
        self.START = '<START>'
        self.END = '<END>'
        self.__word2id = word2id
        self.__id2word = id2word

    def get_word2id(self):
        return self.__word2id

    def get_id2word(self):
        return self.__id2word

    def __getitem__(self, item):
        if self.UNK in self.__word2id:
            return self.__word2id.get(item, self.__word2id[self.UNK])
        return self.__word2id[item]

    def __len__(self):
        return len(self.__word2id)

    def id2word(self, idx):
        return self.__id2word[idx]

    @staticmethod
    def build(data, max_dict_size, freq_cutoff, is_tags):
      
        word_counts = Counter(chain(*data))
        valid_words = [w for w, d in word_counts.items() if d >= freq_cutoff]
        valid_words = sorted(valid_words, key=lambda x: word_counts[x], reverse=True)
        valid_words = valid_words[: max_dict_size]
        valid_words += ['<PAD>']
        word2id = {w: idx for idx, w in enumerate(valid_words)}
        if not is_tags:
            word2id['<UNK>'] = len(word2id)
            valid_words += ['<UNK>']
        return Vocab(word2id=word2id, id2word=valid_words)

    def save(self, file_path):
        with open(file_path, 'w', encoding='utf8') as f:
            json.dump({'word2id': self.__word2id, 'id2word': self.__id2word}, f, ensure_ascii=False)

    @staticmethod
    def load(file_path):
        with open(file_path, 'r', encoding='utf8') as f:
            entry = json.load(f)
        return Vocab(word2id=entry['word2id'], id2word=entry['id2word'])

# %%
### step 5:load dataset

### step 5.1:  use read_corpus function to load training data

sentences, tags = read_corpus(train_data)

# %%
### step 5.2 : use vocab class to convert training data to word and word indice and then save to model files

sent_vocab = Vocab.build(sentences, int(13000), int(1), is_tags=False)
tag_vocab = Vocab.build(tags,int(13000), int(1), is_tags=True)
sent_vocab.save(sent_vocab_file)
tag_vocab.save(tag_vocab_file)

# %%
### step 5.3:  use generate_train_dev_dataset to convert training data, vocab, tag files into train/dev dataset

train_data, dev_data = generate_train_dev_dataset(train_data, sent_vocab, tag_vocab)
print('num of training examples: %d' % (len(train_data)))
print('num of development examples: %d' % (len(dev_data)))
# Out:
# num of training examples: 10443
# num of development examples: 2611

# %%
### step 6 :define model
### step 6.1: define Bi-LSTM-CRF model structure

class BiLSTMCRF(nn.Module):
    def __init__(self, sent_vocab, tag_vocab, dropout_rate=0.5, embed_size=256, hidden_size=256):
        super(BiLSTMCRF, self).__init__()
        self.dropout_rate = dropout_rate
        self.embed_size = embed_size
        self.hidden_size = hidden_size
        self.sent_vocab = sent_vocab
        self.tag_vocab = tag_vocab
        self.embedding = nn.Embedding(len(sent_vocab), embed_size)
        self.dropout = nn.Dropout(dropout_rate)
        self.encoder = nn.LSTM(input_size=embed_size, hidden_size=hidden_size, bidirectional=True)
        self.hidden2emit_score = nn.Linear(hidden_size * 2, len(self.tag_vocab))
        self.transition = nn.Parameter(torch.randn(len(self.tag_vocab), len(self.tag_vocab)))  # shape: (K, K)

    def forward(self, sentences, tags, sen_lengths):
        mask = (sentences != self.sent_vocab[self.sent_vocab.PAD]).to(self.device)  # shape: (b, len)
        sentences = sentences.transpose(0, 1)  # shape: (len, b)
        sentences = self.embedding(sentences)  # shape: (len, b, e)
        emit_score = self.encode(sentences, sen_lengths)  # shape: (b, len, K)
        loss = self.cal_loss(tags, mask, emit_score)  # shape: (b,)
        return loss

    def encode(self, sentences, sent_lengths):
        padded_sentences = pack_padded_sequence(sentences, sent_lengths)
        hidden_states, _ = self.encoder(padded_sentences)
        hidden_states, _ = pad_packed_sequence(hidden_states, batch_first=True)  # shape: (b, len, 2h)
        emit_score = self.hidden2emit_score(hidden_states)  # shape: (b, len, K)
        emit_score = self.dropout(emit_score)  # shape: (b, len, K)
        return emit_score

    def cal_loss(self, tags, mask, emit_score):
        batch_size, sent_len = tags.shape
        # calculate score for the tags
        score = torch.gather(emit_score, dim=2, index=tags.unsqueeze(dim=2)).squeeze(dim=2)  # shape: (b, len)
        score[:, 1:] += self.transition[tags[:, :-1], tags[:, 1:]]
        total_score = (score * mask.type(torch.float)).sum(dim=1)  # shape: (b,)
        # calculate the scaling factor
        d = torch.unsqueeze(emit_score[:, 0], dim=1)  # shape: (b, 1, K)
        for i in range(1, sent_len):
            n_unfinished = mask[:, i].sum()
            d_uf = d[: n_unfinished]  # shape: (uf, 1, K)
            emit_and_transition = emit_score[: n_unfinished, i].unsqueeze(dim=1) + self.transition  # shape: (uf, K, K)
            log_sum = d_uf.transpose(1, 2) + emit_and_transition  # shape: (uf, K, K)
            max_v = log_sum.max(dim=1)[0].unsqueeze(dim=1)  # shape: (uf, 1, K)
            log_sum = log_sum - max_v  # shape: (uf, K, K)
            d_uf = max_v + torch.logsumexp(log_sum, dim=1).unsqueeze(dim=1)  # shape: (uf, 1, K)
            d = torch.cat((d_uf, d[n_unfinished:]), dim=0)
        d = d.squeeze(dim=1)  # shape: (b, K)
        max_d = d.max(dim=-1)[0]  # shape: (b,)
        d = max_d + torch.logsumexp(d - max_d.unsqueeze(dim=1), dim=1)  # shape: (b,)
        llk = total_score - d  # shape: (b,)
        loss = -llk  # shape: (b,)
        return loss

    def predict(self, sentences, sen_lengths):
        batch_size = sentences.shape[0]
        mask = (sentences != self.sent_vocab[self.sent_vocab.PAD])  # shape: (b, len)
        sentences = sentences.transpose(0, 1)  # shape: (len, b)
        sentences = self.embedding(sentences)  # shape: (len, b, e)
        emit_score = self.encode(sentences, sen_lengths)  # shape: (b, len, K)
        tags = [[[i] for i in range(len(self.tag_vocab))]] * batch_size  # list, shape: (b, K, 1)
        d = torch.unsqueeze(emit_score[:, 0], dim=1)  # shape: (b, 1, K)
        for i in range(1, sen_lengths[0]):
            n_unfinished = mask[:, i].sum()
            d_uf = d[: n_unfinished]  # shape: (uf, 1, K)
            emit_and_transition = self.transition + emit_score[: n_unfinished, i].unsqueeze(dim=1)  # shape: (uf, K, K)
            new_d_uf = d_uf.transpose(1, 2) + emit_and_transition  # shape: (uf, K, K)
            d_uf, max_idx = torch.max(new_d_uf, dim=1)
            max_idx = max_idx.tolist()  # list, shape: (nf, K)
            tags[: n_unfinished] = [[tags[b][k] + [j] for j, k in enumerate(max_idx[b])] for b in range(n_unfinished)]
            d = torch.cat((torch.unsqueeze(d_uf, dim=1), d[n_unfinished:]), dim=0)  # shape: (b, 1, K)
        d = d.squeeze(dim=1)  # shape: (b, K)
        _, max_idx = torch.max(d, dim=1)  # shape: (b,)
        max_idx = max_idx.tolist()
        tags = [tags[b][k] for b, k in enumerate(max_idx)]
        return tags

    def save(self, filepath):
        params = { 'sent_vocab': self.sent_vocab,  'tag_vocab': self.tag_vocab, 'args': dict(dropout_rate=self.dropout_rate, embed_size=self.embed_size, hidden_size=self.hidden_size),
            'state_dict': self.state_dict() }
        torch.save(params, filepath)

    @staticmethod
    def load(filepath, device_to_load):
        params = torch.load(filepath, map_location=lambda storage, loc: storage)
        model = BiLSTMCRF(params['sent_vocab'], params['tag_vocab'], **params['args'])
        model.load_state_dict(params['state_dict'])
        model.to(device_to_load)
        return model

    @property
    def device(self):
        return self.embedding.weight.device

# %%
### step 6.2: define loss function for training model

def cal_dev_loss(model, dev_data, batch_size, sent_vocab, tag_vocab, device):

 
    is_training = model.training
    model.eval()
    loss, n_sentences = 0, 0
    with torch.no_grad():
        for sentences, tags in batch_iter(dev_data, batch_size, shuffle=False):
            sentences, sent_lengths = pad(sentences, sent_vocab[sent_vocab.PAD], device)
            tags, _ = pad(tags, tag_vocab[sent_vocab.PAD], device)
            batch_loss = model(sentences, tags, sent_lengths)  # shape: (b,)
            loss += batch_loss.sum().item()
            n_sentences += len(sentences)
    model.train(is_training)
    return loss / n_sentences

# %%
### step 6.3: define all hyper-parameters of Bi-LSTM-CRF model

model_save_path =model_file
optimizer_save_path = optimizer_file
min_dev_loss = float('inf')
device = torch.device('cuda')
patience, decay_num = 0, 0


max_epoch = 3000
log_every = 500
validation_every = 500

dropout=0.5
embed_size= 128
hidden_size= 128
batch_size=1024*2

clip_max_norm= 5.0
lr= 0.001
patience_threshold=0.98
max_patience= 4
max_decay=3
lr_decay= 0.5

# %%
### step 7. instantiate model and hyper-parameters

### step 7.1: instantiate Bi-LSTM-CRF model with word,tag and hyper-paramters

model = BiLSTMCRF(sent_vocab, tag_vocab, float(dropout), int(embed_size), int(hidden_size)).to(device)


for name, param in model.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, 0, 0.01)
        else:
            nn.init.constant_(param.data, 0)

# %%
### step 7.2: define optimizer

optimizer = torch.optim.Adam(model.parameters(), lr=float(lr))
train_iter = 0  # train iter num
record_loss_sum, record_tgt_word_sum, record_batch_size = 0, 0, 0  # sum in one training log
cum_loss_sum, cum_tgt_word_sum, cum_batch_size = 0, 0, 0  # sum in one validation log
record_start, cum_start = time.time(), time.time()

# %%
### step 8: training process

print('start training...')
for epoch in range(max_epoch):
  for sentences, tags in batch_iter(train_data, batch_size=int(batch_size)):
    train_iter += 1
    current_batch_size = len(sentences)
    sentences, sent_lengths = pad(sentences, sent_vocab[sent_vocab.PAD], device)
    tags, _ = pad(tags, tag_vocab[tag_vocab.PAD], device)

    # back propagation
    optimizer.zero_grad()
    batch_loss = model(sentences, tags, sent_lengths)  # shape: (b,)
    loss = batch_loss.mean()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=float(clip_max_norm))
    optimizer.step()

    record_loss_sum += batch_loss.sum().item()
    record_batch_size += current_batch_size
    record_tgt_word_sum += sum(sent_lengths)

    cum_loss_sum += batch_loss.sum().item()
    cum_batch_size += current_batch_size
    cum_tgt_word_sum += sum(sent_lengths)

    if train_iter % log_every == 0:
      print('log: epoch %d, iter %d, %.1f words/sec, avg_loss %f, time %.1f sec' %(epoch + 1, train_iter, record_tgt_word_sum / (time.time() - record_start), record_loss_sum / record_batch_size, time.time() - record_start))
      record_loss_sum, record_batch_size, record_tgt_word_sum = 0, 0, 0
      record_start = time.time()

    if train_iter % validation_every == 0:
      print('dev: epoch %d, iter %d, %.1f words/sec, avg_loss %f, time %.1f sec' % (epoch + 1, train_iter, cum_tgt_word_sum / (time.time() - cum_start),cum_loss_sum / cum_batch_size, time.time() - cum_start))
      cum_loss_sum, cum_batch_size, cum_tgt_word_sum = 0, 0, 0
      model.save(model_save_path)
      torch.save(optimizer.state_dict(), optimizer_save_path)

      dev_loss = cal_dev_loss(model, dev_data, 216, sent_vocab, tag_vocab, device)
      if dev_loss < min_dev_loss * float(patience_threshold):
        min_dev_loss = dev_loss
        model.save(model_save_path)
        torch.save(optimizer.state_dict(), optimizer_save_path)
        patience = 0
      else:
        patience += 1
        if patience == int(max_patience):
          decay_num += 1
          if decay_num == int(max_decay):
            print('Early stop. Save result model to %s' % model_save_path)
            
            lr = optimizer.param_groups[0]['lr'] * float(lr_decay)
            model = BiLSTMCRF.load(model_save_path, device)
            optimizer.load_state_dict(torch.load(optimizer_save_path))
            for param_group in optimizer.param_groups:
              param_group['lr'] = lr
            patience = 0
      print('dev: epoch %d, iter %d, dev_loss %f, patience %d, decay_num %d' %(epoch + 1, train_iter, dev_loss, patience, decay_num))
      cum_start = time.time()
      if train_iter % log_every == 0:
        record_start = time.time()
print('Reached %d epochs, Save result model to %s' % (max_epoch, model_save_path))
# Out:
# start training...
# log: epoch 84, iter 500, 73246.1 words/sec, avg_loss 27.093003, time 250.1 sec
# dev: epoch 84, iter 500, 73246.0 words/sec, avg_loss 27.093003, time 250.1 sec
# dev: epoch 84, iter 500, dev_loss 1.523411, patience 0, decay_num 0
# log: epoch 167, iter 1000, 73055.4 words/sec, avg_loss 11.250969, time 250.8 sec
# dev: epoch 167, iter 1000, 73055.3 words/sec, avg_loss 11.250969, time 250.8 sec
# dev: epoch 167, iter 1000, dev_loss 1.383882, patience 0, decay_num 0
# log: epoch 250, iter 1500, 72972.2 words/sec, avg_loss 4.873937, time 250.5 sec
# dev: epoch 250, iter 1500, 72972.2 words/sec, avg_loss 4.873937, time 250.5 sec
# dev: epoch 250, iter 1500, dev_loss 1.497915, patience 1, decay_num 0
# log: epoch 334, iter 2000, 72869.7 words/sec, avg_loss 2.726739, time 251.4 sec
# dev: epoch 334, iter 2000, 72869.7 words/sec, avg_loss 2.726739, time 251.4 sec
# dev: epoch 334, iter 2000, dev_loss 1.554167, patience 2, decay_num 0
# log: epoch 417, iter 2500, 72745.4 words/sec, avg_loss 1.886146, time 251.8 sec
# dev: epoch 417, iter 2500, 72745.4 words/sec, avg_loss 1.886146, time 251.8 sec
# dev: epoch 417, iter 2500, dev_loss 1.659809, patience 3, decay_num 0
# log: epoch 500, iter 3000, 72801.1 words/sec, avg_loss 1.430344, time 251.1 sec
# dev: epoch 500, iter 3000, 72801.0 words/sec, avg_loss 1.430344, time 251.1 sec
# dev: epoch 500, iter 3000, dev_loss 1.759136, patience 4, decay_num 1
# log: epoch 584, iter 3500, 72974.6 words/sec, avg_loss 1.147752, time 251.0 sec
# dev: epoch 584, iter 3500, 72974.6 words/sec, avg_loss 1.147752, time 251.0 sec
# dev: epoch 584, iter 3500, dev_loss 1.858391, patience 5, decay_num 1

# %%
#### step 9: Test model with test dataset

# %%
#### step 9.1: reload word and tag files
sent_vocab = Vocab.load(sent_vocab_file)
tag_vocab = Vocab.load(tag_vocab_file)

# %%
### step 9.2: load test dataset
sentences, tags = read_corpus(test_data)

# %%
### step 9.3: convert test dataset from text into indice
sentences_indice = words2indices(sentences[:4], sent_vocab)

# %%
### step 9.4 : preview the test dataset as indice
sentences=sentences[:4]

# %%
sentences_indice
# Out:
# [[0,
#   5,
#   1746,
#   4471,
#   12577,
#   12577,
#   10318,
#   1459,
#   379,
#   4,
#   12577,
#   88,
#   12577,
#   177,
#   1],
#  [0, 1871, 426, 63, 228, 205, 1],
#  [0, 468, 1],
#  [0, 149, 537, 330, 223, 13, 2337, 315, 330, 223, 1]]

# %%
### step 9.5 : convert tag into indice
tags_indice = words2indices(tags[:4], tag_vocab)

# %%
### step 9.6 : combine test datasets and tags into test object
test_objects = list(zip(sentences_indice, tags_indice))

# %%
### step 9.7: reload model

device = torch.device('cuda' )
model = BiLSTMCRF.load(model_file, device)
print('start testing...')
print('using device', device)
# Out:
# start testing...
# using device cuda

# %%
model.eval()
# Out:
# BiLSTMCRF(
#   (embedding): Embedding(13002, 128)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (encoder): LSTM(128, 128, bidirectional=True)
#   (hidden2emit_score): Linear(in_features=256, out_features=27, bias=True)
# )

# %%
### step 9.8 : define function to convert token into vocabs

def tokens_to_spans( tokens, tags):
  spans = []
  curr, start, end, ent_cls = 0, None, None, None
  sentence = " ".join(tokens)

  for token, tag in zip(tokens, tags):

    if tag == "O":
      if ent_cls is not None:
        spans.append((start, end, ent_cls))
        start, end, ent_cls = None, None, None

    elif tag.startswith("B-"):
        ent_cls = tag.split("-")[1]
        start = curr
        end = curr + len(token)
    else:  # I-xxx
        try:
          end += len(token) + 1
        except:
          end = 0
          end += len(token) + 1
                    # advance curr
    curr += len(token) + 1
               
            # handle remaining span
    if ent_cls is not None:
      spans.append((start, end, ent_cls))
  return sentence, spans

# %%
### step 10 : try model with dataset without tag
### step 10.1 : load test dataset with tag
test_sentences=[]
with open(test_data,'r',encoding='utf-8') as f:
  for line in f.read().split('\n\n'):
        line=[l.split('\t') for l in line.split('\n')]
        words=[i[0] for i in line if len(i)==2]
        test_sentences.append(' '.join(words))

# %%
# !pip install intervaltree
# Out:
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from intervaltree) (2.3.0)

# %%
from intervaltree import Interval, IntervalTree

# %%
### step 10.2: define hyper-parameters
max_len = 223

# %%
### step 10.3 : run model with test dataset 
for test_sent in test_sentences[:500]:
  ori_tokens=test_sent.split(' ')
  tokens=['<START>']+ori_tokens+['<END>']

  tokens_idx = words2indices([tokens], sent_vocab)[0]
 
  lengths = len(tokens_idx)


    
  padded_data=tokens_idx + [sent_vocab[sent_vocab.PAD]] * (max_len - len(tokens_idx))
  padded_tokens_idx, tokens_idx_len=torch.tensor([padded_data], device=device),[lengths]
  pred_tag_idx = model.predict(padded_tokens_idx, tokens_idx_len)[0][1:-1]
  pred_tags=[tag_vocab.id2word(p) for p in pred_tag_idx]
  print(ori_tokens)
  print(pred_tags,'\n')
# Out:
# ['Mr.', 'Koh', 'How', 'Thim', '(高厚琛先生)', '125', 'Kim', 'Tian', 'Road', '#05-96', 'Singapore', '160125', 'Singaporean']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['ICBCI', '(Joint', 'Lead', 'Manager', 'only)']
# ['B-J', 'O', 'O', 'O', 'O']
#
# ['DBS']
# ['S-J']
#
# ['United', 'Kingdom', 'J.P.', 'Morgan', 'Securities', 'LLC,', 'or', 'J.P.', 'Morgan']
# ['O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'B-J', 'E-J']
#
# ['Industry', 'consultant', 'Ipsos', 'Sdn.', 'Bhd.', '23rd', 'Floor,', 'Centerpoint', 'North', 'Mid', 'Valley', 'City,', 'Lingkaran', 'Syed', 'Putra', '59200', 'Kuala', 'Lumpur', 'Malaysia']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Auditor', 'and', 'Reporting', 'Accountants', 'Deloitte', 'Touche', 'Tohmatsu']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG']
#
# ['Legal', 'advisers', 'to', 'our', 'Company', 'As', 'Hong', 'Kong', 'law:', 'Robertsons', 'Solicitors,', '57th', 'Floor', 'The', 'Center', '99', "Queen's", 'Road', 'Central', 'Solicitors']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'S-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-ORG']
#
# ['BOCI']
# ['B-ORG']
#
# ['Mr.', 'Alan', 'C.Y.', 'Yung']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['GLAM', 'Capital', 'Limited', 'A', 'licensed', 'corporation', 'under', 'the', 'SFO', 'to', 'engage', 'in', 'type', '1', '(dealing', 'securities),', '4', '(advising', 'on', 'securities)', 'and', '9', '(asset', 'management)', 'regulated', 'activities']
# ['B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['DBS']
# ['S-J']
#
# ['Cayman', 'Islands', 'Principal', 'Share', 'Registrar', 'Maples', 'Fund', 'Services', '(Cayman)', 'Limited']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['King&Wood', 'Mallesons']
# ['B-ORG', 'E-ORG']
#
# ['ABCI']
# ['S-J']
#
# ['Dr.', 'John', 'G.', 'Wilcox', '875', 'S', 'Madison', 'Ave', 'Pasadena,', 'California', 'United', 'States']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['ICBCI', '(Joint', 'Lead', 'Manager', 'only)']
# ['B-J', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Tao', 'Yu', '(陶宇先生)', 'Room', '401,', 'Unit', '1,', 'Block', '29', 'No.', '18', 'Zidong', 'Road', 'Qixia', 'District,', 'Nanjing', 'Jiangsu', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['YFS']
# ['S-J']
#
# ['50/F,', 'Shanghai', 'World', 'Financial', 'Center', '100', 'Century', 'Avenue', 'Pudong', 'New', 'Area', 'Shanghai,', 'China', '200120', 'Receiving', 'bank', 'Bank', 'of', '(Hong', 'Kong)', 'Limited']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'E-ORG', 'O', 'B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['155', 'Citigroup', 'Global', 'Markets', 'Limited', '(in', 'relation', 'to', 'the', 'International', 'Offering', 'only)']
# ['B-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Company', 'secretary', 'Mr.', 'Leung', 'Cheuk', 'Wai', '(Certified', 'Public', 'Accountant)', 'Flat', 'D,', '8/F,', 'Tower', '6', 'Tung', 'Shan', 'Mansion', 'Taikoo', 'Shing', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Huang', 'Qingping', '(黃清平)', 'Unit', '1-101,', 'Block', '12', 'No.', '288', 'Caochangmen', 'Street', 'Gulou', 'District', 'Nanjing,', 'Jiangsu', 'Province', 'The', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Audit', 'committee', 'Ms.', 'Lim', 'Yan', 'Xin', 'Reina', '(林延芯)', '(Chairlady)', 'Mr.', 'Poon', 'Lai', 'Yin', 'Michael', '(潘禮賢)', 'Dr.', 'Wong', 'Ho', 'Ki', '(黃浩麒)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Fong', 'Wo,', 'Felix', '(方和)', '.', 'Flat', 'D,', '9/F', 'Repulse', 'Bay', 'Towers', '119A', 'Road', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Legal', 'advisers', 'to', 'the', 'Sole', 'Sponsor,', 'Lead', 'Manager,', 'Joint', 'Bookrunners', 'and', 'Underwriters']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE']
#
# ['Sole', 'Sponsor', 'Titan', 'Financial', 'Services', 'Limited', 'Suites', '3201–02,', '32/F', 'COSCO', 'Tower', 'Grand', 'Millennium', 'Plaza', '183', "Queen's", 'Road', 'Central', 'Hong', 'Kong', '(A', 'licenced', 'corporation', 'carrying', 'on', 'Type', '1', '(dealing', 'in', 'securities)', 'and', '6', '(advising', 'corporate', 'finance)', 'regulated', 'activities', 'under', 'the', 'SFO)']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Ching', 'Man', 'Yeung', '(楊靜文)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Other', 'Joint', 'Global', 'Coordinator,', 'Bookrunner', 'and', 'Lead', 'Manager']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE']
#
# ['Receiving', 'bank', '.', 'Bank', 'of', 'China', '(Hong', 'Kong)', 'Limited', 'Tower', '1', 'Garden', 'Road', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Compliance', 'adviser', 'Grande', 'Capital', 'Limited', '(A', 'licensed', 'corporation', 'carrying', 'on', 'Type', '6', '(advising', 'corporate', 'finance)', 'regulated', 'activity', 'under', 'the', 'SFO)']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Wang', 'Xuning', '(Chairman)', 'Hui', 'Chi', 'Kin', 'Max', 'Stassi', 'Anastas', 'Anastassov', 'Wong', 'Tin', 'Yau', 'Kelvin', 'Timothy', 'Roberts', 'Warner', 'Yang', 'Xianxiang']
# ['B-PERSON', 'E-PERSON', 'O', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O']
#
# ['Mr.', 'Lin', 'Hing', 'Lung', '(連興隆先生)', '57/F,', 'Block', '27,', 'Celestial', 'Heights', '80', 'Sheung', 'Shing', 'Street', 'Ho', 'Man', 'Tin,', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Yi', 'Xu', '徐逸', '.', 'Room', '2301,', 'No.3,', 'Lane', '339', 'Binjiang', 'Avenue,', 'Pudongxin', 'District', 'Shanghai', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sole', 'Sponsor', 'Fortune', 'Financial', 'Capital', 'Limited', '43/F,', 'Cosco', 'Tower', '183', "Queen's", 'Road', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Elstone', 'Securities', 'Limited', 'Suite', '1601–04,', '16/F', 'West', 'Tower,', 'Shun', 'Tak', 'Centre', '168–200', 'Connaught', 'Road', 'Central', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['109', 'Legal', 'advisers', 'to', 'our', 'Company']
# ['O', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE']
#
# ['Mr.', 'Wong', 'Wing', 'Keung', 'Meyrick', '(王泳強)', 'Room', '1907,', 'Block', 'M', 'Kornhill', 'Quarry', 'Bay', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Zang', 'Weizhong', '(臧偉仲)', 'Room', '201,', 'No.', '1', 'Sicheng', 'Road', 'Tianhe', 'District,', 'Guangzhou', 'Guangdong', 'Province,', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'PRC', 'law:', 'Allbright', 'Law', 'Offices', '6/F.,', 'Office', 'Tower', 'C1', 'Oriental', 'Plaza', 'No.1', 'East', 'Chang', 'An', 'Avenue', 'Beijing', 'The']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Wu', 'Chun', 'Sing', '(鄔晉昇)', 'Flat', 'D,', '31/F,', 'Tower', '3,', 'The', 'Grandiose', 'Tseung', 'Kwan', 'O,', 'New', 'Territories', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Floor,', 'The', 'Center', '99', "Queen's", 'Road', 'Central', 'Hong', 'Kong', 'As', 'to', 'Singapore', 'law:']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Zhang', 'Yahan', '(張雅寒)']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Head', 'Office', 'and', 'Principal', 'Place', 'of', 'Business', 'in', 'the', 'PRC', '.', 'Unit', 'A2', 'No.', '700', 'Wanrong', 'Road', 'Shanghai']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'Hong', 'Kong', 'laws', 'Fairbairn', 'Catley', 'Low', '&', 'Solicitors,', '23/F,', 'Shui', 'On', 'Centre', '6-8', 'Harbour', 'Road']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Global', 'Coordinators', '.']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'O']
#
# ['Mr.', 'Zang', 'Lin', '(臧凛先生)', 'No.', '601,', 'Unit', '3', '07', 'Building,', 'Tianbao', 'New', 'Town', 'Plot', 'Zhangbei', 'Xian', 'Zhangjiakou', 'County', 'Hebei', 'Province', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Realord', 'Asia', 'Pacific', 'Securities', 'Limited', 'A', 'corporation', 'licensed', 'to', 'engage', 'in', 'Type', '1', '(dealing', 'securities)', 'regulated', 'activities', 'under', 'the', 'SFO']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Suite', '501,', 'Tower', 'W3', 'Oriental', 'Plaza', 'No.1', 'East', "Chang'an", 'Avenue', 'Dongcheng', 'District', 'Beijing,', 'China,', '100738', 'Cushman', '&', 'Wakefield', 'K.K.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Huang', 'Hai', 'Hu', 'Zaixin', 'Wang', 'Xiaojun', 'Peng']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['Mr.', 'Tam', 'Chun', 'Wai', 'Edwin']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['AWSG', 'International', 'Securities', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Auditor', 'and', 'reporting', 'accountant']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE']
#
# ['YANG', 'Herong', '(楊和榮)', 'No.', '577-163,', 'Siming', 'Middle', 'Road', 'Ningbo,', 'Zhejiang', 'Province', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Lam', 'Ka', 'Wing', 'Flat', 'D,', '65/F.,', 'Tower', '3', 'Grand', 'Promenade', '38', 'Tai', 'Hong', 'Street', 'Sai', 'Wan', 'Ho', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'YANG', 'Xuemei', '(楊雪梅)', 'Flat', 'E,', '27F,', 'Block', '3', '8', 'Oi', 'King', 'Street', 'Hunghom', 'Bay', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Bookrunners', 'and', 'Lead', 'Managers', 'Mason', 'Securities', 'Limited']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG']
#
# ['Ms.', 'Gan', 'Shuya', '(干述亞)', 'Room', '901,', 'Unit', '2', 'District', 'A,', 'Huangjia', 'Yili', 'Yunhe', 'Cangzhou', 'City', 'Hebei', 'Province', 'PRC']
# ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['PricewaterhouseCoopers', '22/F,', "Prince's", 'Building', 'Central', 'Hong', 'Kong']
# ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Tseng', 'Chin', 'I', '(曾瀞漪)', '2/F', 'No.', '4', 'Man', 'King', 'Terrace', 'Clearwater', 'Bay', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Lead', 'Managers', 'J.P.', 'Morgan', 'Securities', '(Asia', 'Pacific)', 'Limited', '(in', 'relation', 'to', 'Hong', 'Kong', 'Public', 'Offering)']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Chen', 'Shiping', '(陳仕平)', 'Unit', '801,', 'Block', '3B', 'Taihu', 'Mingzhu', 'Yuan', 'Sanjing', 'Street', 'Xinbei', 'District', 'Changzhou', 'City', 'Jiangsu', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'the', 'PRC', 'law:', 'Global', 'Law', 'Office', '27th', 'Floor', 'Tower', 'B,', 'China', 'Resources', 'Land', 'Building', 'No.', '9668', 'Shennan', 'Avenue', 'Nanshan', 'District,', 'Shenzhen']
# ['O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['28/F,', 'Chater', 'House', '8', 'Connaught', 'Road', 'Central', 'Hong', 'Kong', 'J.P.', 'Morgan', 'Securities', 'plc', '(Joint', 'Bookrunner', 'and', 'Joint', 'Lead', 'Manager', 'in', 'relation', 'to', 'International', 'Offering', 'only)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'XIE', 'Yanli', '(謝豔麗)', 'Room', '301,', 'Block', '22', 'Chunshui', 'Yuan', 'Jinyuan', 'Unit', 'Taiping', 'Avenue', 'Wenling', 'City,', 'Zhejiang', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['20/F,', 'Central', '88', 'Nos.', '88–98', 'Des', 'Voeux', 'Road', 'Hong', 'Kong', 'As', 'to', 'Singapore', 'laws', 'Shook', 'Lin', '&', 'Bok', 'LLP', '1', 'Robinson', '#18-00', 'AIA', 'Tower', '048542', 'Cayman', 'Islands']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Leung', 'Wai-Keung,', 'Richard', '38/F,', 'Gloucester', 'Tower', 'The', 'Landmark', 'Central,', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Jieyu', 'ZOU', '(鄒潔羽)', 'Room', '302,', 'Building', '157', 'No.', '378', 'Luheng', 'Road', 'Minhang', 'District', 'Shanghai', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Fu', 'Jingqiu', '(富晶秋)', 'Flat', '801,', 'Block', '6', 'Lijing', 'Garden', 'Yushan', 'Town', 'Kunshan', 'City', 'Jiangsu', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Lead', 'Manager', 'ZMF', 'Asset', 'Management', 'Limited', 'A', 'licensed', 'corporation', 'permitted', 'to', 'carry', 'out', 'type', '1', '(dealing', 'in', 'securities),', '4', '(advising', 'on', 'securities)', 'and', '9', '(asset', 'management)', 'regulated', 'activities', 'under', 'the', 'SFO', 'Unit', '2502,', '25/F,', 'World', 'Wide', 'House', '19', 'Des', 'Voeux', 'Road', 'Central,', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Li', 'Chau', 'Yuen,', 'Senior', 'Counsel']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O']
#
# ['Auditors', 'and', 'Reporting', 'Accountants', 'Ernst', '&', 'Young', 'Certified', 'Public', '22/F,', 'CITIC', 'Tower', '1', 'Tim', 'Mei', 'Avenue,', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Lead', 'Managers', 'China', 'International', 'Capital', 'Corporation', 'Hong', 'Kong', 'Securities', 'Limited']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Head', 'office', 'in', 'the', 'PRC', '5/F,', 'Tower', '2', '515', 'Yishan', 'Road', 'Shanghai', 'The']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Yuzhou', 'Financial', 'Holdings', 'Limited', 'A', 'licensed', 'corporation', 'under', 'the', 'SFO', 'to', 'conduct', 'type', '1', '(dealing', 'in', 'securities),', '4', '(advising', 'on', 'securities)', 'and', '9', '(asset', 'management)', 'regulated', 'activities']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Kingsway', 'Financial', 'Services', 'Group', 'Limited', '7/F,', 'Tower', 'One,', 'Lippo', 'Centre,', '89', 'Queensway,', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Chen', 'Shimin', '(陳世敏)', 'Unit', '699', 'Hongfeng', 'Road', 'Pudong', 'New', 'Area', 'Shanghai,', 'The', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Lin', 'Lili', '(林莉莉)', 'Room', '902', 'Block', '2,', 'Zone', 'A', 'Jinjiang', 'Century', 'Residence', 'No.', '351', 'Sanfeng', 'Road', 'Hangcheng', 'Sub-district', 'Changle', 'District,', 'Fuzhou', 'Fujian,', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Augustine', 'Securities', 'Company', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Choi', 'Wai', 'Chan', 'Rua.', 'Central', 'Areia', 'Preta', 'Block', '1,', 'Floor', '19,', 'Flat', 'A', 'Ed.', 'The', 'Residencia', 'Macau']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'Singapore', 'law:', 'Rajah', '&', 'Tann', 'LLP', '9', 'Battery', 'Road', '#25–01', '049910']
# ['O', 'O', 'E-ORG', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Chan', 'Shuk', 'Fong', '(陳淑芳女士)', '30K,', 'The', 'Masterpiece', '18', 'Hanoi', 'Road', 'Tsim', 'Sha', 'Tsui', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ernst', '&', 'Young', '22/F,', 'CITIC', 'Tower', '1', 'Tim', 'Mei', 'Avenue', 'Central', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Bookrunners', 'Space', 'Securities', 'Limited', 'A', 'licensed', 'corporation', 'under', 'the', 'SFO', 'to', 'engage', 'in', 'type', '1', '(dealing', 'securities)', 'regulated', 'activity']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Lu', 'Zhen', '(陸真).', '.', 'Room', '1704,', 'Building', '6', 'Yuanyi', 'Baizhuang', 'No.', '88', 'Chaohu', 'South', 'Street', 'Baohe', 'District', 'Hefei', 'City', 'Anhui', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'U.S.', 'laws:', 'Reed', 'Smith', 'LLP', '599', 'Lexington', 'Avenue', '22nd', 'Floor', 'New', 'York,', 'NY10022', 'United', 'States']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Chan', 'Tak', 'Sun', 'Sammy', '3/F,', 'Elegance', 'Court', '212', 'Castle', 'Peak', 'Road', 'Cheung', 'Sha', 'Wan', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Skadden,', 'Arps,', 'Slate,', 'Meagher', '&', 'Flom', 'LLP', 'and', 'affiliates']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Sole', 'Sponsor', 'Innovax', 'Capital', 'Limited', 'A', 'licensed', 'corporation', 'to', 'carry', 'on', 'Type', '1', '(dealing', 'in', 'securities)', 'and', '6', '(advising', 'corporate', 'finance)', 'regulated', 'activities', 'under', 'the', 'SFO', 'Room', '2002,', '20/F', 'Chinachem', 'Century', 'Tower', '178', 'Gloucester', 'Road', 'Wanchai', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'TANG', 'Renhong', '(唐任宏)', 'Room', '201,', 'Unit', '3,', 'Building', '8', 'Courtyard', 'No.1,', "Xi'erqi", 'West', 'Road', 'Haidian', 'District,', 'Beijing', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Wong', 'Loke', 'Tan', '68', 'Begonia', 'Drive', 'Singapore', '809926', 'Singaporean']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['China', 'Insights', 'Consultancy', 'Limited', '10F,', 'Block', 'B,', "Jing'an", 'International', 'Center', '88', 'Puji', 'Road', 'District', 'Shanghai', 'The', 'PRC']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Tax', 'advisers', 'SHINEWING', 'and', 'Business', 'Advisory', 'Limited', '43/F,', 'Lee', 'Garden', 'One', '33', 'Hysan', 'Avenue,', 'Causeway', 'Bay', 'Hong', 'Kong']
# ['I-ORG', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Global', 'Coordinators', 'Haitong', 'International', 'Securities', 'Company', 'Limited']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Shao', 'Yongjun', 'Unit', 'ABC,', '30/F,', 'Mirae', 'Asset', 'Tower', 'No.166,', 'Lu', 'Jia', 'Zui', 'Ring', 'Road', 'Shanghai', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Company', 'secretary', 'Ms.', 'Ng', 'Wing', 'Yan', '(ACIS,', 'ACS)']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O']
#
# ['Sponsor', 'Grande', 'Capital', 'Limited', 'A', 'licensed', 'corporation', 'to', 'carry', 'on', 'type', '6', '(advising', 'corporate', 'finance)', 'regulated', 'activities', 'under', 'the', 'SFO', 'Room', '2701,', '27/F', 'Tower', 'One,', 'Admiralty', 'Center', '18', 'Harcourt', 'Road', 'Admiralty,', 'Hong', 'Kong']
# ['B-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Zeus', 'Securities', 'Limited', 'A', 'corporation', 'licensed', 'to', 'carry', 'out', 'Type', '1', '(dealing', 'in', 'securities)', 'regulated', 'activity', 'under', 'the', 'SFO']
# ['B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Principal', 'Place', 'of', 'Business', 'and', 'Head', 'Office', 'in', 'the', 'PRC', '25th', 'Floor', 'Hong', 'Yang', 'Building', 'No.', '9', 'Daqiao', 'North', 'Road', 'Nanjing', 'Jiangsu', 'Province,']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sponsor', 'and', 'Joint', 'Bookrunner', 'Alliance', 'Capital', 'Partners', 'Limited', 'A', 'corporation', 'licensed', 'under', 'the', 'SFO', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities)', '6', '(advising', 'corporate', 'finance)', 'regulated', 'activities', 'as', 'defined']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'Hong', 'Kong', 'law', 'Iu,', 'Lai', '&', 'Li', 'Solicitors', 'and', 'Notaries', 'Rooms', '2201,', '2201A', '2202', '22nd', 'Floor,', 'Tower', 'I', 'Admiralty', 'Centre', '18', 'Harcourt', 'Road']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Fu', 'Lui', '(府磊)', 'Flat', 'D,', '7/F,', 'Block', '8', 'Pristine', 'Villa', '18', 'Pak', 'Lok', 'Path', 'Sha', 'Tin', 'New', 'Territories', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'Cayman', 'Islands', 'law', 'Walkers', '(Hong', 'Kong)', '15/F,', 'Alexandra', 'House', '18', 'Chater', 'Road', 'Central', 'Hong', 'Kong']
# ['O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Company', 'secretary', 'Ms.', 'Yuen', 'Wing', 'Yan,', 'Winnie(袁頴欣女士)FCIS,', 'FCS(PE)', 'Level', '54,', 'Hopewell', 'Centre', '183', "Queen's", 'Road', 'East', 'Hong', 'Kong', 'Winnie']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-PERSON']
#
# ['Mr.', 'CHAN', 'Shui', 'Yip', '(陳垂燁先生)', '(Vice', 'Chairman', 'and', 'Vice', 'President)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Principal', 'place', 'of', 'business', 'in', 'Hong', 'Kong', 'Unit', '629A,', '6th', 'Floor', 'Star', 'House,', 'No.', '3', 'Salisbury', 'Road', 'Tsim', 'Sha', 'Tsui,', 'Kowloon']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Tang', 'Tin', 'Lok', 'Stephen', '(Chairman)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Mr.', 'Lee', 'Cheuk', 'Hung', '(李卓雄先生)', 'Flat', 'G,', '28/F.,', 'Tower', '22', 'Hoi', 'Yue', 'Mansion,', 'Riviera', 'Gardens', '1–5', 'Yi', 'Lok', 'Street', 'Tsuen', 'Wan,', 'New', 'Territories', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Unit', 'B,', '17/F', 'United', 'Centre', '95', 'Queensway', 'Hong', 'Kong', 'Mr.', 'Poon', 'Soon', 'Huat', '(', '方順發先生', ')']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O']
#
# ['Shan', 'Minqi', 'Room', '902,', 'Unit', '3', 'Building', '4,', 'Pastoral', 'Luyunyuan', 'Banshan', 'Town,', 'Gongshu', 'District', 'Hangzhou,', 'Zhejiang', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['YCIH', 'Zhaotong', 'Development', 'Building', 'Avenue', 'Zhaoyang', 'District,', 'Yunnan,', 'PRC']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['HUANG', 'Yulin', '(黃玉林)', 'Room', '701,', 'Unit', '1,', 'Block', '7', '38', 'Qing', 'Shan', 'South', 'Road', 'Donghu', 'District,', 'Nanchang', 'Jiangxi,', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Authorised', 'representatives', '(for', 'the', 'purpose', 'of', 'Listing', 'Rules)', 'Mr.', 'Zeng', 'Ming', 'Room', '1003,', 'Unit', '2', 'Building', 'B,', 'Lian', 'Chuang', 'Garden', 'No.', '28', 'Zhangjiang', 'North', 'Road', 'Zhanggong', 'District', 'Ganzhou', 'Jianxi', 'Province', 'PRC']
# ['B-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Legal', 'Advisors', 'to', 'the', 'Underwriters', 'as', 'Hong', 'Kong', 'and', 'United', 'States', 'law:']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ravinder', 'Singh', 'THAKRAN', '27A', 'Swettenham', 'Road', 'Singapore', '248128', 'Indian']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'ZHENG', 'Catherine', 'Wei', 'Hong', 'Room', '602,', 'Building', '19', 'Shang', 'Shan', 'Ruo', 'Shui', 'Ya', 'Garden', '398', 'Xin', 'Nan', 'Road', 'Cun', 'Town', 'Panyu', 'District,', 'Guangzhou', 'City', 'Guangdong', 'Province,', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Chan', 'Kwok', 'Wing', 'Kelvin', '(陳國榮先生)', 'May', 'Tai', 'Keung', 'Nicholas', '(梅大強先生)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Great', 'Roc', 'Capital', 'Securities', 'Limited', '(a', 'corporation', 'licenced', 'to', 'carry', 'out', 'Type', '1', '(dealing', 'in', 'securities)', 'and', '4', '(advising', 'on', 'regulated', 'activities', 'under', 'the', 'SFO)']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Zeng', 'Ming', '(曾明)', 'Room', '1003,', 'Unit', '2', 'Building', 'B,', 'Lian', 'Chuang', 'Garden', 'No.', '28', 'Zhangjiang', 'North', 'Road', 'Zhanggong', 'District', 'Ganzhou', 'Jiangxi', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Nomination', 'committee', 'Mr.', 'Choo', 'Chih', 'Chien', 'Benjamin', '(Chairman)', 'Chiam', 'Soon', 'Chian', '(Zhan', 'Shunquan)', 'Michael', 'Shi', 'Guan', 'Wah']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Beijing', 'DHH', 'Law', 'Firm']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Ling', 'Sheng', 'Shyan', '77,', 'Taman', 'Berjaya', 'Pulau', 'Tikus', '10350', 'George', 'Town', 'Pinang', 'Malaysia']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Auditor', 'and', 'reporting', 'accountant', 'KPMG', '8/F,', "Prince's", 'Building', '10', 'Chater', 'Road', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Chen', 'Danhua', '(陳丹華)', 'Apartment', '2355,', '23/F', 'Tower', '8', 'Parkview', 'Rise', '–', 'HK', '88', 'Tai', 'Tam', 'Reservoir', 'Road', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Property', 'Valuer', 'Jones', 'Lang', 'LaSalle', 'Corporate', 'Appraisal', 'and', 'Advisory', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Ms.', 'Li', 'Yan', '(李艷)', 'No.', '8', 'Kangle', 'North', 'First', 'Street', 'Duanzhou', 'District', 'Zhaoqing', 'City', 'Guangdong', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Singapore', 'GST', 'Adviser', 'Baker', 'Tilly', 'TFW', 'LLP', '600', 'North', 'Bridge', 'Road', '#05–01', 'Parkview', 'Square', '188778']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['China', 'Galaxy', 'International', 'Securities', '(Hong', 'Kong)', 'Co.,', 'Limited', '20/F', 'Wing', 'On', 'Centre', '111', 'Connaught', 'Road', 'Central', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Ng', 'Chee', 'Kwong,', 'Colin', '(吳志光先生)', 'Wee', 'Kang', 'Keng', 'Lim', 'Sooi', 'Kheng', 'Patrick', '(林瑞慶先生)', 'Kho', 'Chuan', 'Thye', '(高泉泰先生)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Company', 'Secretary', 'Wang', 'Dong', '(', '王冬', ')']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'E-PERSON', 'O', 'O', 'O']
#
# ['Nixon', 'Peabody', 'CWL']
# ['B-ORG', 'I-ORG', 'E-ORG']
#
# ['Ms.', 'Liu', 'Huiyan', '(劉慧妍)', 'Room', '2101', 'No.7', 'Hui', 'Yue', 'Second', 'Street', 'Hai', 'Zhu', 'District', 'Guangzhou', 'City', 'The', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sole', 'Global', 'Coordinator', 'Guotai', 'Junan', 'Securities', '(Hong', 'Kong)', 'Limited', '27th', 'Floor,', 'Low', 'Block', 'Grand', 'Millennium', 'Plaza', '181', "Queen's", 'Road', 'Central', 'Hong', 'Kong', '(A', 'licenced', 'corporation', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities)', 'and', '4', '(advising', 'regulated', 'activities', 'under', 'the', 'SFO)']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Li', 'Huaxiong', '(李華雄)', '(Chairperson)']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O']
#
# ['Internal', 'control', 'consultant', 'Baker', 'Tilly', 'Consultancy', '(Singapore)', 'Pte', 'Ltd', '600', 'North', 'Bridge', 'Road,', '#05–01', 'Parkview', 'Square', 'Singapore', '188778']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Blair', 'Sterling', 'Johnson', '&', 'Martinez,', 'P.C.']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Lefei', 'SUN', '(孫樂非)', '12/F,', 'Bauhinia', 'Serviced', 'Apartment', '119', 'Connaught', 'Road', 'Central', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sang', 'Woo', '(Kirin)', 'Securities', 'Limited', '(A', 'licensed', 'corporation', 'to', 'carry', 'out', 'type', '1', '(dealing', 'in', 'securities)', 'and', '4', '(advising', 'on', 'regulated', 'activities', 'under', 'the', 'SFO)']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Leung', 'Martin', 'Oh', 'Man', '(Chairman)', 'Lau', 'Koong', 'Yep', 'Yuen', 'King', 'Sum', 'Kwok', 'Fan']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Zhang', 'Jianguo', '(張建國)', '.', 'No.510', 'Lane', '415', 'Longdong', 'Avenue', 'Pudong', 'New', 'District', 'Shanghai,', 'China']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'WANG', 'Liyan', '(王立彥)', 'No.', '1003,', 'Unit', '5,', 'Building', '1', 'Courtyard', '11', 'Andingmen', 'Outer', 'Street', 'Dongcheng', 'District', 'Beijing', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Yau', 'Siu', 'Yeung', '(游紹揚)', 'Flat', 'A,', '19/F.,', 'Block', '3', 'Beverley', 'Heights', '56', 'Cloud', 'View', 'Road', 'North', 'Point', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Independent', 'industry', 'consultant', 'Frost', '&', 'Sullivan', 'Limited', 'Suite', '1706,', 'One', 'Exchange', 'Square', '8', 'Connaught', 'Place', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Li', 'Hongkun', '(李紅琨)', 'Room', '901,', 'Unit', '3,', 'Building', '18', 'Kangyuan', 'Residential', 'Quarter', '237', 'Longquan', 'Road', 'Wuhua', 'District,', 'Kunming', 'Yunnan,', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Sun', 'Haitao']
# ['B-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['Mr.', 'Sheng', 'Zijiu', '(盛子九)', 'Room', '14-2-602', 'Caihe', 'Ziou', 'Estate', 'Jianggan', 'District,', 'Hangzhou', 'Zhejiang,', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Liu', 'Dajin', 'Room', '404,', 'Building', '11', '1', 'Ji', 'Cen', 'Street', 'Mei', 'District', 'Xiamen', 'City', 'Fujian', 'Province,', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Room', 'A,', '29/F,', 'Block', '4', 'Kingsford', 'Terrace', '8', 'King', 'Tung', 'Street', 'Diamond', 'Hill', 'Hong', 'Kong', 'Audit', 'Committee', 'Mr.', 'Lee', 'Tak', 'Fai', 'Thomas', '(Chairman)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Ms.', 'Xu', 'Jing', '(徐靜)', '(CICPA', ',', 'FCCA,', 'CPA)']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O']
#
# ["Dato'", 'Kwan', 'Siew', 'Deeg', '3,', 'Jalan', 'Setia', 'Tropika', 'U13/24B', 'Eco', 'Park', '40170', 'Shah', 'Alam', 'Selangor', 'Malaysia']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ruibang', 'Securities', 'Limited']
# ['B-ORG', 'I-ORG', 'E-ORG']
#
# ['As', 'to', 'PRC', 'laws:', 'Zhong', 'Lun', 'Law', 'Firm', '6/F,', 'ONE', 'IFC', '(HSBC', 'Building)', '8', 'Century', 'Avenue', 'Pudong', 'New', 'Area', 'Shanghai', 'China']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Yang', 'Dongtao', '(楊東濤)', '.', 'Room', '502,', 'Unit', '1,', 'Block', '3', 'Zhonghai', 'Fenghuang', 'Garden', '1', 'Qingliangmen', 'Street', 'Nanjing,', 'Jiangsu', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'LEE', 'Wai', 'Hung', 'Garic', '(李偉鴻先生)', '(HKICPA', '—', 'Non-Practising)', 'Flat', 'C,', '40th', 'Floor', '18', 'Farm', 'Road', 'To', 'Kwa', 'Wan', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Hui', 'Hung', 'Kwan', 'Dr.', 'Liang', 'Dongke']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'B-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['Grand', 'View', 'Securities', 'Limited', 'A', 'licensed', 'corporation', 'under', 'the', 'SFO', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities)', 'regulated', 'activities']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Principal', 'place', 'of', 'business', 'in', 'Hong', 'Kong', '31/F,', 'Excel', 'Centre', '483A', 'Castle', 'Peak', 'Road', 'Cheung', 'Sha', 'Wan']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'PRC', 'law', 'Beijing', 'Jingtian', '&', 'Gongcheng', 'Law', 'Firm', 'Unit', '05–06,', '16/F,', 'China', 'Resources', 'Tower,', 'No.', '2666', 'Keyuan', 'South', 'Road,', 'Nanshan', 'District,', 'Shenzhen,']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Bookrunners', 'Zhong', 'Jia', 'Securities', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Chew', 'Keat', 'Yeow', '(Zhou', 'Jieyao)', '(周洁耀)', 'Apt', 'Blk', '516', 'Jurong', 'West', 'Street', '52', '#08-41', 'Singapore', '640516', 'Singaporean', 'Zhou', 'Jieyao']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'E-PERSON']
#
# ['PO', 'Box', '309', 'Ugland', 'House', 'Grand', 'Cayman', 'KY1-1104', 'Islands']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Compliance', 'adviser', 'Innovax', 'Capital', 'Limited', 'Room', '2002,', '20th', 'Floor', 'Chinachem', 'Century', 'Tower', '178', 'Gloucester', 'Road', 'Wanchai', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Clifford', 'Chance', '27/F,', 'Jardine', 'House', 'One', 'Connaught', 'Place', 'Hong', 'Kong']
# ['B-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Registered', 'office', 'Vistra', '(Cayman)', 'Limited', 'P.O.', 'BOX', '31119', 'Grand', 'Pavilion', 'Hibiscus', 'Way,', '802', 'West', 'Bay', 'Road', 'Cayman', 'KY1-1205', 'Islands']
# ['O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['GLAM', 'Capital', 'Limited']
# ['B-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Chan', 'Oi', 'Fat', '(陳愛發先生)', 'Flat', 'SA,', '10th', 'Floor,', 'Block', '1', 'Phase', '3,', 'Festival', 'City', 'Tai', 'Wai,', 'New', 'Territories', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Suites', '4505-06,', '45/F', 'Tower', '1,', 'Lippo', 'Centre', '89', 'Queensway', 'Hong', 'Kong', '(a', 'licensed', 'corporation', 'under', 'SFO', 'to', 'carry', 'out', 'type', '6', '(advising', 'on', 'corporate', 'finance)', 'regulated', 'activity', 'the', 'SFO)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Bookrunners', 'and', 'Lead', 'Managers', 'CCB', 'International', 'Capital', 'Limited', 'A', 'corporation', 'licensed', 'under', 'the', 'SFO', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities),', '4', '(advising', 'securities)', '6', 'corporate', 'finance)', 'regulated', 'activities']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Cheng', 'Ching-Long', '(鄭景隆)', '2–2102,', 'Huamin', 'Family', 'Garden', 'Kunshan', 'City', 'Jiangsu', 'Province', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Dr.', 'Ge', 'Junbo', '(葛均波)', 'Room', '1547,', 'Block', '16', 'Xietu', 'Road', 'Xuhui', 'District,', 'Shanghai', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'MAK', 'Po', 'Man', 'Cherie']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['Company', 'secretary', 'Ms.', 'Lam', 'Wing', 'Chi,', 'ACS,', 'ACIS', 'Level', '54,', 'Hopewell', 'Centre', '183', "Queen's", 'Road', 'East', 'Hong', 'Kong', 'Chi']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-PERSON']
#
# ['Fortune', '(HK)', 'Securities', 'Limited', '43/F', 'Cosco', 'Tower', '183', "Queen's", 'Road', 'Central', 'Hong', 'Kong', 'A', 'corporation', 'licensed', 'by', 'the', 'SFC', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities)', 'regulated', 'activity', 'under', 'SFO']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Huang', 'Yu', '(黃煜)', 'Flat', 'G,', '22/F,', 'Tower', '3', 'Sorrento', '1', 'Austin', 'Road', 'West', 'Tsim', 'Sha', 'Tsui,', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Corporate', 'Governance', 'and', 'Nominating', 'Committee']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE']
#
# ['Mr.', 'Wei', 'Hai', 'Yan', '(魏海燕)', 'Flat', '23F,', 'Jingxi', 'Building', '26', 'Jingtian', 'North', 'First', 'Street', 'Futian', 'District', 'Shenzhen', 'Guangdong', 'Province', '(廣東省深圳市福田區景田北一街26號', '景西大廈23F)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Cricket', 'Square', 'Hutchins', 'Drive,', 'P.O.', 'Box', '2681', 'Grand', 'Cayman,', 'KY1-1111', 'Cayman', 'Islands']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Audit', 'committee', 'Mr.', 'Lim', 'Wee', 'Pin', '(Chairman)', 'Jong', 'Voon', 'Hoo', 'Koh', 'Boon', 'Chiao']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Guosen', 'Securities', '(HK)', 'Capital', 'Company', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['TSUI', 'Wing', 'Tak', '(', '徐穎德', ')']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O']
#
# ['Credit', 'Suisse', '(Hong', 'Kong)', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['28-29/F,', "Queen's", 'Road', 'Centre', '152', 'Central', 'Hong', 'Kong', 'I', 'Win', 'Securities', 'Limited']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Grand', 'View', 'Securities', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Joint', 'Global', 'Coordinators', 'and', 'Bookrunners', 'Giraffe', 'Capital', 'Limited']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG']
#
# ['Compliance', 'officer', 'Mr.', 'Ho', 'Ka', 'Ki', '(何家淇先生)']
# ['B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Mr.', 'Liu', 'Hongwu', '(劉洪武)', '156', 'Shuangshu', 'North', 'Team', 'Heizhuanghu', 'Township', 'Chaoyang', 'District', 'Beijing', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Receiving', 'Banks', 'DBS', 'Bank', '(Hong', 'Kong)', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Shen', 'Hao', '(沈浩)', '.', 'No.100,', 'Lane', '288', 'Yunle', 'Road', 'Minhang', 'District', 'Shanghai,', 'China']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Chen', 'Yuan,', 'Rita', '(陳練瑛)', 'Flat', 'A,', '5/F', '45', 'Fa', 'Po', 'Street', 'Village', 'Gardens', 'Phase', 'B', 'Kowloon', 'Tong,', 'Hong', 'Kong']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['One', 'Embarcadero', 'Centre', '32nd', 'Floor', 'San', 'Francisco,', 'CA', '94111', 'United', 'States', 'of', 'America']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Jia', 'Yuan', 'Law', 'Offices', 'F408,', 'Ocean', 'Plaza', '158', 'Fuxing', 'Men', 'Nei', 'Street', 'Xicheng', 'District', 'Beijing,', 'China']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Cricket', 'Square', 'Hutchins', 'Drive', 'P.', 'O.', 'Box', '2681', 'Grand', 'Cayman', 'KY1-1111', 'Islands']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['CGS-CIMB', 'Securities', '(Hong', 'Kong)', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Reynolds', 'Porter', 'Chamberlain']
# ['B-ORG', 'I-ORG', 'E-ORG']
#
# ['Joint', 'Company', 'Secretaries', '-------------', 'Mr.', 'Xiao', 'Tianchi', '(肖天馳)', '72', 'Saina', 'Rongfu', 'Huaxiang', 'Road', 'Langfang', 'Economic', 'and', 'Technological', 'Development', 'Area', 'Hebei', 'Province', 'PRC']
# ['B-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Assistant', 'company', 'secretary']
# ['B-TITLE', 'I-TITLE', 'E-TITLE']
#
# ['Mr.', 'LO', 'Chi', 'Wang', '(羅智弘)', 'Flat', 'H,', '18/F,', 'Block', '3', 'Saddle', 'Ridge', 'Garden', 'Ma', 'On', 'Shan,', 'New', 'Territories', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Jiang', 'Qian', 'Yuan', 'Jun', 'Remuneration', 'committee', '(Chairman)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'B-TITLE', 'E-TITLE', 'O']
#
# ['Mr.', 'Li', 'Weiqing', '(李維慶)', 'Room', '602,', 'Unit', '2,', 'Building', '2', '388', 'Jinan', 'Road', 'Donggang', 'District', 'Rizhao', 'City', 'Shandong', 'Province', 'PRC']
# ...
#
# ['Mr.', 'Yang', 'Zhiqiang', '(楊志強)', 'Room', 'F,', '35/F', 'Block', '16', 'Yee', 'Tsui', 'Court', 'South', 'Horizons', 'Aberdeen', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Godefriedus', 'Jelte', 'Heijboer']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON']
#
# ['Mr.', 'NI', 'Zhengdong', '(倪正東)', 'ZHANG', 'Min']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O']
#
# ['Mr.', 'Lau', 'Koong', 'Yep', '(Chairman)', 'Leung', 'Martin', 'Oh', 'Man', 'Yuen', 'King', 'Sum', 'Kwok', 'Fan']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['ABCI', 'Securities', 'Company', 'Limited', '(as', 'a', 'Joint', 'Lead', 'Manager)']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Yang', 'Cao', '(曹洋)', 'Suite', '1408,', 'Huawen', 'International', 'Mansion', '999', 'West', 'Zhongshan', 'Road', 'Changning', 'District', 'Shanghai', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Lui', 'Wing', 'Wai', '(呂永懷)', '(Chairman', 'of', 'the', 'Board)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Liu', 'Jiang', '(劉江)', 'No.', '7,', 'North', 'Road,', 'East', '4th', 'Ring,', 'Chaoyang', 'District,', 'Beijing,', 'China', '(中國北京市朝陽區東四環北路七號)']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'U.S.', 'law', 'Nixon', 'Peabody', 'LLP', 'One', 'Embarcadero', 'Center,', '32nd', 'Floor', 'San', 'Francisco', 'CA', '94111', 'United', 'States']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Lam', 'Fung', 'Eng', 'No.', '24,', 'Jalan', 'Bukit', 'Impian', '22', 'Taman', 'Emas', '81300', 'Skudai,', 'Johor', 'Malaysia']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Liu', 'Jifeng', '(劉紀鋒)', 'Tongbai', 'Village', 'Guangyang', 'District', 'Langfang', 'Hebei', 'Province', 'PRC']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Wu', 'Bin', '(吳濱)', 'Room', '612,', 'No.', '13,', 'Kaiming', 'Alley', 'Haishu', 'District,', 'Ningbo', 'Zhejiang,', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Authorized', 'Representatives', '.', 'Mr.', 'Michael', 'James', 'Sheehan', '4983', 'Lusk', 'Lane', 'Flower', 'Mound,', 'TX,', '75028', 'United', 'States']
# ['B-TITLE', 'E-TITLE', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Legal', 'advisers', 'to', 'our', 'Company', 'as', 'Hong', 'Kong', 'laws', 'David', 'Fong', '&', 'Co.', 'Solicitors,', 'Unit', 'A,', '12/F', 'China', 'Overseas', 'Building', '139', 'Hennessy', 'Road', 'Wanchai']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Hong', 'Kong', 'Underwriters', 'Innovax', 'Securities', 'Limited']
# ['O', 'O', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG']
#
# ['Alpha', 'Financial', 'Group', 'Limited', 'Room', 'A,', '17/F.', 'Fortune', 'House', '61', 'Connaught', 'Road', 'Central', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['WANG', 'Honggang', '(王洪剛)', '.', 'Non-executive', 'Director', 'Room', '302', 'No.1,', 'Lane', '99', 'Dongxiu', 'Road', 'Pudong', 'New', 'District', 'Shanghai']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Zhang', 'Zhifeng', '(張智峰)', 'Huali', 'College', 'Guangdong', 'University', 'of', 'Technology', 'Zengcheng', 'District', 'Guangzhou', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['China', 'Everbright', 'Securities', '(HK)', 'Limited', '12/F,', 'Centre', '108', 'Gloucester', 'Road', 'Wanchai', 'Hong', 'Kong', '(a', 'licensed', 'corporation', 'permitted', 'to', 'carry', 'on', 'type', '1', '(dealing', 'in', 'securities),', '4', '(advising', '6', 'corporate', 'finance)', 'and', '9', '(asset', 'management)', 'regulated', 'activities', 'under', 'the', 'SFO)']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mason', 'Securities', 'Limited', '19/F', 'Lee', 'Garden', 'Three', '1', 'Sunning', 'Road', 'Causeway', 'Bay', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Lu', 'Yuan', '(陸遠)', 'Room', '12,', 'Floor', '4,', 'Unit', '1,', '39', 'Zhonghua', 'South', 'Road,', 'Tiedong', 'District,', 'Anshan,', 'Liaoning', 'Province,', 'China']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Industry', 'Consultant', 'Ipsos', 'Asia', 'Limited', '6/F,', 'China', 'Life', 'Center,', 'Tower', 'A', 'One', 'HarbourGate', '18', 'Hung', 'Kuen', 'Road', 'Hom', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Nomination', 'committee', 'Mr.', 'Xu', 'Kai', '(chairman)']
# ['O', 'O', 'O', 'O', 'O', 'O']
#
# ['Audit', 'committee', 'Mr.', 'Lee', 'Siu', 'Hang', 'Foster', '(李兆鏗)', '(Chairperson)', 'Ms.', 'Tam', 'Hon', 'Shan', 'Celia', '(譚漢珊)', 'Tian', 'Tao', '(田濤)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Nisa', 'Leung', '(梁頴宇女士)', '1/F.,', '15', 'Wang', 'Chiu', 'Road', 'Kowloon', 'Bay,', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Bai', 'Linsen', '(柏林森)', 'Room', '501,', 'Building', '85,', 'No.', '18', 'Wenchang', 'Middle', 'Road', 'Guangling', 'District,', 'Yangzhou', 'City', 'Jiangsu', 'Province,', 'China']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Gu', 'Yunchang', '(顧雲昌)', '(formerly', 'known', 'as', 'Yongchuang', '(顧勇闖))']
# ['B-PERSON', 'B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'E-PERSON', 'O']
#
# ['Remuneration', 'committee', 'Mr.', 'Wang', 'Yuqing', '(王裕清)', '(Chairman)']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Bookrunners', 'and', 'Lead', 'Managers', 'Lego', 'Securities', 'Limited', '(A', 'licensed', 'corporation', 'to', 'carry', 'out', 'type', '1', '(dealing', 'in', 'securities)', 'regulated', 'activity', 'under', 'the', 'SFO)']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Authorised', 'representatives', '(for', 'the', 'purpose', 'of', 'GEM', 'Listing', 'Rules)', 'Ms.', 'Liang', 'Wei', '(梁薇)', 'No.', '092,', 'Hupan', 'District,', 'Banshanhaoyuan', 'Dongguan', 'City,', 'Guangdong', 'Province,', 'China']
# ['B-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sole', 'Sponsor', 'ABCI', 'Capital', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Au', 'Yeung', 'Po', 'Fung', '(Chairman)']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O']
#
# ['Mr.', 'LAW', 'Ming', 'Kin', '(羅明健)', 'Room', 'B,', '20/F,', 'Block', '14', 'Provident', 'Centre', 'Wharf', 'Road', 'North', 'Point', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Hu', 'Rongen', '(胡戎恩)', 'No.', '179,', 'Lane', '388', 'Sichen', 'Highway', 'Songjiang', 'District', 'Shanghai', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'WANG', 'Wenming', '(王文明)', 'No.', '3', 'Gaoqiu', 'Maoyang', 'Village,', 'Wenqiao', 'Town', 'Wenling', 'City,', 'Zhejiang', 'Province', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Legal', 'advisers', 'to', 'the', 'Company', 'As', 'Hong', 'Kong', 'law:', 'Kwok', 'Yih', '&', 'Chan', 'Suites', '2103-05,', '21', 'st']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O']
#
# ['Legal', 'advisers', 'to', 'the', 'Sole', 'Sponsor,', 'Joint', 'Bookrunners', 'and', 'Lead', 'Managers', 'Underwriters']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE']
#
# ['Legal', 'Advisors', 'to', 'the', 'Joint', 'Sponsors,', 'Global', 'Coordinators', 'and', 'Underwriters']
# ['B-TITLE', 'B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE']
#
# ['Mr.', 'Zhang', 'Junjie', '(張俊傑)', 'Phase', '2,', 'Tianzhu', 'Yutianxia', 'Linyin', 'Road', 'Shunyi', 'District', 'Beijing,', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Sponsor']
# ['S-TITLE']
#
# ['Mr.', 'Lam', 'Hing', 'Lun', 'Alain', '(林慶麟)', 'Flat', 'A,', '13th', 'Floor', 'Tower', '6', 'Residence', 'Bel-Air', 'Island', 'South', '28', 'Avenue', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Auditor', 'and', 'Reporting', 'Accountant', 'Deloitte', 'Touche', 'Tohmatsu', '35/F,', 'One', 'Pacific', 'Place', '88', 'Queensway', 'Hong', 'Kong']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Liu', 'Yanqun', '(劉彥群)', 'Room', '17-1-202,', 'No.', '188', 'Mengdu', 'Street', 'Jianye', 'District,', 'Nanjing', 'the', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Ms.', 'Zhu', 'Xin', '(Chairwoman)', 'Mr.', 'Shiu', 'Kwan', 'Danny', 'Wai', 'Dr.', 'Zheng', 'Yin']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Qiu', 'Jianyu', 'No.', '43', 'Jia', 'Dai', 'Dong', 'Qing', 'Village', 'Zheng', 'Lu', 'Town', 'Tianning', 'District,', 'Changzhou', 'Jiangsu', 'Province', 'China']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['18th', 'Floor', 'United', 'Centre', '95', 'Queensway', 'Hong', 'Kong', 'As', 'to', 'Singapore', 'law', 'Virtus', 'Law', 'LLP', '1', 'Raffles', 'Place', '#18-61', 'Tower', '2', '048616', 'U.S.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Citigroup', 'Global', 'Markets', 'Asia', 'Limited', '(in', 'relation', 'to', 'the', 'Hong', 'Kong', 'Public', 'Offering)']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Legal', 'Advisers', 'to', 'our', 'Company', 'As', 'Hong', 'Kong', 'laws:', 'King', '&', 'Wood', 'Mallesons', '13/F,', 'Gloucester', 'Tower', 'The', 'Landmark', '15', "Queen's", 'Road', 'Central']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['As', 'to', 'PRC', 'law:', 'Jingtian', '&', 'Gongcheng', '34/F,', 'Tower', '3,', 'China', 'Central', 'Place', '77', 'Jianguo', 'Road', 'Chaoyang', 'District', 'Beijing']
# ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Supreme', 'China', 'Securities', 'Limited']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Name', 'Residential', 'Address', 'Nationality', 'Executive', 'Directors', 'Mr.', 'MAO', 'Chen', 'Cheney', '(', '毛晨', ')']
# ['O', 'O', 'O', 'O', 'B-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O']
#
# ['Orient', 'Securities', '(Hong', 'Kong)', 'Limited', 'A', 'licensed', 'corporation', 'to', 'carry', 'out', 'Type', '1', '(dealing', 'in', 'securities)', 'and', '4', '(advising', 'on', 'regulated', 'activities', 'under', 'the', 'SFO', 'Unit', '2803–07,', '28/F,', 'Wing', 'On', 'House,', 'No.', '71', 'Des', 'Voeux', 'Road', 'Central,', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Joint', 'Sponsors,', 'Global', 'Coordinators', '(in', 'alphabetical', 'order)']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'O', 'O', 'O']
#
# ['GAO', 'Yongmei', '(高永梅)', '.', 'Unit', '608,', 'Level', '6,', 'Building', 'No.', '2', 'Xi', 'Guang', 'Plaza', 'Gong', 'Yuan', 'North', 'Road', 'Xin', 'Cheng', 'District', "Xi'an,", 'Shaanxi', 'China']
# ['B-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Receiving', 'bank', 'DBS', 'Bank', '(Hong', 'Kong)', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Sole', 'Representative', 'CCB', 'International', 'Capital', 'Limited']
# ['B-TITLE', 'E-TITLE', 'B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Mr.', 'Ngan', 'Tim', 'Wing', 'Flat', 'C,', 'Ground', 'Floor', 'Village', 'Gardens', 'Phase', 'C', '40', 'Fa', 'Po', 'Street', 'Kowloon', 'Hong', 'Kong']
# ['B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Conyers', 'Dill', '&', 'Pearman', 'Cricket', 'Square,', 'Hutchins', 'Drive', 'P.O.', 'Box', '2681,', 'Grand', 'Cayman', 'KY1-1111', 'Islands', 'as', 'to', 'Indonesia', 'law:']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Members', 'of', 'the', 'Nomination', 'Committee', 'Mr.', 'Ng', 'Chi', 'Chiu(吳志超)', '(Chairman)', 'Prof.', 'Chau', 'Kwong', 'Wing', '(鄒廣榮)', 'Yip', 'Chun', 'On', '(葉俊安)', 'Chiu']
# ['B-TITLE', 'I-TITLE', 'I-TITLE', 'I-TITLE', 'E-TITLE', 'B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'I-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O-PERSON']
#
# ['Kingsway', 'Financial', 'Services', 'Group', 'Limited', '7/F', 'Tower', 'One,', 'Lippo', 'Centre', '89', 'Queensway,', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mouette', 'Securities', 'Company', 'Limited', 'a', 'licenced', 'corporation', 'under', 'the', 'SFO', 'to', 'conduct', 'type', '1', '(dealing', 'in', 'securities)', 'and', '4', '(advising', 'on', 'regulated', 'activities', 'Room', '1301,', '13th', 'Floor', 'Tung', 'Wai', 'Commercial', 'Building', '109-111', 'Gloucester', 'Road', 'Wanchai,', 'Hong', 'Kong']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Wu', 'Guojia', '(吳國佳)', 'No.', '2,', 'Lane', '99', 'Yiminhe', 'Road', 'Hongkou', 'District', 'Shanghai,', 'PRC']
# ['B-PERSON', 'I-PERSON', 'E-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Shu', 'Jin', 'Law', 'Firm']
# ['B-ORG', 'I-ORG', 'I-ORG', 'E-ORG']
#
# ['Joint', 'Sponsors', '.', 'BNP', 'Paribas', 'Securities', '(Asia)', 'Limited', '63/F,', 'Two', 'International', 'Finance', 'Centre', '8', 'Street', 'Central', 'Hong', 'Kong']
# ['B-TITLE', 'E-TITLE', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'E-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# ['Mr.', 'Qu', 'Wenzhou', '(屈文洲)', '.', 'Room', '401', 'No.645,', 'Hexiangxi', 'Road', 'Siming', 'District', 'Xiamen', 'Fujian', 'Province', 'China']
# ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
with torch.no_grad(): 
 for sent_sample,sent_sample_token_idx in zip(test_sample,test_token_idx):
  
    lengths = len(sent_sample_token_idx)
    max_len = 88

    
    padded_data=sent_sample_token_idx + [sent_vocab[sent_vocab.PAD]] * (max_len - len(sent_sample_token_idx))
 
    padded_sent_idx, sent_idx_len=torch.tensor([padded_data], device=device),[lengths]

    pred_tag_idx = model.predict(padded_sent_idx, sent_idx_len)[0][1:-1]

    pred_tags=[tag_vocab.id2word(p) for p in pred_tag_idx]
    
    
    sent_sample,sent_span=tokens_to_spans( sent_sample[1:-1],pred_tags)
    sent_span=list(set(sent_span))
    t = IntervalTree()
    for s in sent_span:
      t[s[0]:s[1]] = s[2]
    t_=t.copy()
    t_.merge_overlaps()
    print(r'sample sentence:',sent_sample)
    for tt in list(t_):
        t_start,t_end=tt.begin,tt.end
  
        for s in sent_span:
          if s[0]==t_start and s[1]==t_end:
            print(r'entity:         ',sent_sample[t_start:t_end],':',s[2])
    print('\n')
    #print(sent_sample,sent_span)
   #   sent, pred_tags = sent[1: -1],  pred_tags[1: -1]
   #   print(sent,pred_tags)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
#
# sample sentence: Authorised representatives ZHANG Lianghong (張梁洪) Shanxianghu Xiaozu Pufa Village Committee Changning Town Boluo County Guangdong Province, the PRC*
#
#
# sample sentence: Compliance adviser Alliance Capital Partners Limited a licensed corporation under the SFC to carry on Type 1 (dealing in securities) and 6 (advising corporate finance) regulated activities SFO Room 1502–1503A, Wing On House 71 Des Voeux Road Central Central, Hong Kong
# entity:          Alliance Capital Partners Limited : ORG
# entity:          Compliance adviser : TITLE
#
#
# sample sentence: Company secretary . Mr. Lau Wai Piu Patrick (劉偉彪) (Fellow member of the Hong Kong Institute Certified Public Accountants) Unit B, 13th Floor Winsan Tower 98 Thomson Road Wanchai,
# entity:          Company secretary : TITLE
# entity:          Mr. Lau Wai Piu Patrick : PERSON
#
#
# sample sentence: United Kingdom J.P. Morgan Securities LLC, or J.P. Morgan (Joint Bookrunner in relation to the International Offering only)
# entity:          J.P. Morgan : J
# entity:          J.P. Morgan Securities LLC, : ORG
#
#
# sample sentence: Mr. WU Tai Cheung (胡大祥) Unit H, 9/F., Tower 6 Mantin Heights 28 Sheung Shing Street Ho Man Tin Kowloon Hong Kong
# entity:          Mr. WU Tai Cheung : PERSON
#
#
# sample sentence: Joint Company Secretaries
# entity:          Joint Company Secretaries : TITLE
#
#
# sample sentence: Remuneration Committee Mr. Wan Wai Wing(温蔚榮) (Chairman) Wing
# entity:          Remuneration Committee : TITLE
# entity:          Mr. Wan Wai : PERSON
#
#
# sample sentence: Banco Santander, S.A. (in relation to International Offering only)
# entity:          Banco Santander, S.A. : TITLE
#
#
# sample sentence: Legal Advisors to the Sole Sponsor and Underwriters
# entity:          Legal Advisors to the Sole Sponsor and Underwriters : TITLE
#
#
# sample sentence: AMTD Global Markets Limited
# entity:          AMTD Global Markets Limited : ORG
#
#
# sample sentence: Safety Adviser Mr. Chan Wai Shing
# entity:          Safety Adviser : TITLE
# entity:          Mr. Chan Wai Shing : PERSON
#
#
# sample sentence: Sinomax Securities Limited 2705–6, 27/F Tower One, Lippo Centre 89 Queensway Hong Kong
# entity:          Sinomax Securities Limited : ORG
#
#
# sample sentence: Mr. WAN Yushan (萬玉山) Room 1403, Unit 2, Building 7 438 Hanzhongmen Street Gulou District Nanjing, Jiangsu PRC
# entity:          Mr. WAN Yushan (萬玉山) : PERSON
#
#
# sample sentence: Mr. Chen Zhibin (陳志斌先生) Room 602, No. 292 Longjin Xi Road Liwan District, Guangzhou Guangdong Province PRC
# entity:          Mr. Chen Zhibin (陳志斌先生) : PERSON
#
#
# sample sentence: China Galaxy International Securities (Hong Kong) Co., Limited 20th Floor, Wing On Centre 111 Connaught Road Central Hong Kong
# entity:          China Galaxy International Securities (Hong Kong) Co., Limited : ORG
#
#
# sample sentence: Mr. Ang Kok Kwang (Hong Guoguang) (洪虢光) 51 Jalan Bunga Rampai #03-02 Singapore 538420 Ms. Leung Hoi Yan (梁皚欣), HKICS Hong Guoguang
# entity:          Mr. Ang Kok Kwang : PERSON
# entity:          Ms. Leung Hoi Yan : PERSON
#
#
# sample sentence: WANG Kaiguo (王開國) No. 3, Lane 133 Honggu Road Shanghai, China
# entity:          WANG Kaiguo (王開國) : PERSON
#
#
# sample sentence: As to the Cayman Islands law: Maples and Calder (Hong Kong) LLP 53rd Floor, The Center 99 Queen's Road Central Hong Kong
# entity:          Maples and Calder (Hong Kong) LLP : ORG
#
#
# sample sentence: Saikrishna & Associates
# entity:          Saikrishna & Associates : ORG
#
#
# sample sentence: King & Wood Mallesons 18th Floor, East Tower World Financial Center 1 Dongsanhuan Zhonglu Chaoyang District Beijing PRC
# entity:          King & Wood Mallesons : ORG
#
#
# sample sentence: Ms. Zhong Ruoqin Room 402, Unit 1, Building 5 Triumphal Arch Department Jianggan District Hang Zhou, China
# entity:          Ms. Zhong Ruoqin : PERSON
#
#
# sample sentence: Mr. Wei Gao (高偉) (FCIS, FCS (PE))
# entity:          Mr. Wei Gao : PERSON
#
#
# sample sentence: Joint Bookrunners Cinda International Capital Limited A licensed corporation under the SFO to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities
# entity:          Joint Bookrunners : TITLE
# entity:          Cinda International Capital Limited : ORG
#
#
# sample sentence: Mr. DIAO Qinyi (刁欽義) Room 901, Unit 6, Floor 9 Building 3, Fourth Block Donghuashinanli Chongwen District Beijing PRC
# entity:          Mr. DIAO Qinyi (刁欽義) : PERSON
#
#
# sample sentence: Chang Kam Lai (張錦麗) (HKICPA) Rm 2008, 20/F Oi Wing Hse, Tsz CRT PH 3 Wan Shan, Kowloon Hong Kong
# entity:          Chang Kam Lai : PERSON
#
#
# sample sentence: Lundgrens Law Firm P/S
# entity:          Lundgrens Law Firm P/S : TITLE
#
#
# sample sentence: Legal advisers to our Company ---------As Hong Kong law:
# entity:          Legal advisers to our Company : TITLE
#
#
# sample sentence: Elstone Securities Limited Suite 1601–04, 16/F West Tower, Shun Tak Centre 168–200 Connaught Road Central Hong Kong (a licensed corporation under the SFO to carry out type 1 (dealing in securities) and 4 (advising on regulated activities SFO)
# entity:          Elstone Securities Limited : ORG
#
#
# sample sentence: Frost & Sullivan (Beijing) Inc., Shanghai Branch Co. 1018, Tower B Greenland Center 500 Yunjin Road Shanghai, China
# entity:          Frost & Sullivan (Beijing) Inc., Shanghai Branch Co. : ORG
#
#
# sample sentence: TD King Securities Limited
# entity:          TD King Securities Limited : ORG
#
#
# sample sentence: Compliance Adviser Dakin Capital Limited
# entity:          Dakin Capital Limited : ORG
# entity:          Compliance Adviser : TITLE
#
#
# sample sentence: Receiving Banks Bank of China (Hong Kong) Limited 1 Garden Road Hong Kong
# entity:          Bank of China (Hong Kong) Limited : ORG
# entity:          Receiving Banks : TITLE
#
#
# sample sentence: Chuenman Securities Limited Office A, 10/F Sang Woo Building, 227-228 Gloucester Road, Wanchai Hong Kong
# entity:          Chuenman Securities Limited : ORG
#
#
# sample sentence: Joint Lead Managers CRIC Securities Company Limited (A licensed corporation to carry out type 1 (dealing in securities), 4 (advising on securities) and 9 (asset management) regulated activities under the SFO)
# entity:          Joint Lead Managers : TITLE
# entity:          CRIC Securities Company Limited : ORG
#
#
# sample sentence: AnJie Law Firm
# entity:          AnJie Law Firm : ORG
#
#
# sample sentence: LC Lawyers LLP
# entity:          LC Lawyers LLP : ORG
#
#
# sample sentence: AMC Wanhai Securities Limited
# entity:          AMC Wanhai Securities Limited : ORG
#
#
# sample sentence: Estrada Marginal do Hipódromo No. 56-68 Edifício Industrial Lee Cheung 13 Andar D Macau
#
#
# sample sentence: Fortune (HK) Securities Limited 43/F Cosco Tower 183 Queen's Road Central Hong Kong (A licensed corporation to carry out type 1 (dealing in securities) regulated activities under the SFO)
# entity:          Fortune (HK) Securities Limited : ORG
#
#
# sample sentence: 24/F, HKRI Centre Two Taikoo Hui 288 Shi Men Yi Road Shanghai China Auditors *
#
#
# sample sentence: Ms. Yuen Wing Yan, Winnie(袁頴欣女士)FCIS, FCS(PE) Level 54, Hopewell Centre 183 Queen's Road East Hong Kong Winnie
# entity:          Ms. Yuen Wing : PERSON
#
#
# sample sentence: Joint Lead Managers Macquarie Capital Limited
# entity:          Macquarie Capital Limited : ORG
# entity:          Joint Lead Managers : TITLE
#
#
# sample sentence: Principal place of business in the PRC . Room 402 and 501–502, Block F3 TCL International E City 1001 Zhongshan Park Road Nanshan District Shenzhen Guangdong Province
#
#
# sample sentence: Mr. Huang Liang Zhang Wei
# entity:          Mr. Huang Liang Zhang Wei : PERSON
#
#
# sample sentence: Units 15-17, Ground Floor Bangunan Haji Hassan Abdullah, Jalan Gadong Kampung Menglait Bandar Seri Begawan BE3919 Brunei Darussalam
#
#
# sample sentence: Dr. Liu Linqing (劉林青) Room 702, 7th Floor, Unit 4, Sun Tower 2, No. 22, Democratic 2nd Road, Wuchang District, Wuhan, PRC
# entity:          Dr. Liu Linqing : PERSON
#
#
# sample sentence: 150 China International Capital Corporation Hong Kong Securities Limited
# entity:          150 China International Capital Corporation Hong Kong Securities Limited : ORG
#
#
# sample sentence: Tao ZHU (朱濤) Room 1101, Unit 6, Building 8 Taida Shidai Garden, Shunda Street Binhai New Area Tianjin PRC
# entity:          Tao ZHU (朱濤) : PERSON
#
#
# sample sentence: Citigroup Global Markets Limited (in relation to the International Offering only) 33 Canada Square Canary Wharf London E14 5LB United Kingdom
# entity:          Citigroup Global Markets Limited : ORG
#
#
# sample sentence: Mr. Yang Xiaoye (楊小業) Room 1402, No. 1 Yijingyi Street Taiping Town, Conghua District Guangzhou, the PRC* (中國廣州巿從化區太平鎮 怡景一街1號1402室)
# entity:          Mr. Yang Xiaoye : PERSON
#
#
# sample sentence: Mr. Liu Chang (劉暢) 1/F, Building 7, Hongqiao Zhenro Center Lane 666, Shenhong Road Minhang District Shanghai PRC
# entity:          Mr. Liu Chang (劉暢) : PERSON
#
#
# sample sentence: 12th Floor, Tower A Fenglin International Plaza Phase II 420 Road, Xuhui District Shanghai, China
#
#
# sample sentence: Mr. Lo Chi Hung Flat B, 14/F, Chinese (盧志雄) Hoi Ning Mansion (Block 17)
# entity:          Mr. Lo Chi Hung : PERSON
#
#
# sample sentence: 18 Harbour Road Wanchai Hong Kong Legal Advisors to the Underwriters As and U.S. law:
# entity:          Legal Advisors to the Underwriters : TITLE
#
#
# sample sentence: Mr. Luo Changlin (羅昌林) Room 601, Building 6 Phase 3, Meili City No. 2 Vanke Road Chenghua District Chengdu PRC
# entity:          Mr. Luo Changlin (羅昌林) : PERSON
#
#
# sample sentence: Mr. Wang Haiping (王海平) 103#, Building 8 Jinshuiwan Small Community Jiaojiang District Taizhou, Zhejiang Province PRC
# entity:          Mr. Wang Haiping : PERSON
#
#
# sample sentence: Authorised representatives (for the purpose of Listing Rules) Mr. Law Hau Kit 38/F, 23 Celestial Heights 80 Sheung Shing Street Kowloon Hong Kong
# entity:          Authorised representatives : TITLE
# entity:          Mr. Law Hau Kit : PERSON
#
#
# sample sentence: Wu Chengze (吳承澤) Group 1, Street Committee Shuangyingzihuizu Town Shuangyang District Changchun City Jilin Province PRC
#
#
# sample sentence: 218 Xinghu Street, Building B7, 7th Floor Suzhou Industrial Park Suzhou, Jiangsu China
# entity:          Building B7, : ORG
#
#
# sample sentence: Walkers Corporate Limited Cayman Centre 27 Hospital Road, George Town Grand KY1-9008 Islands
# entity:          Walkers Corporate Limited : ORG
#
#
# sample sentence: Mr. Ng Siu Hin Stanley (吳肇軒) Flat A, 8th Floor, Block 2 Castello Lek Yuen Road Shatin, New Territories Hong Kong
# entity:          Mr. Ng Siu Hin Stanley (吳肇軒) : PERSON
#
#
# sample sentence: Mr. Danke YU (余丹柯) 34 Belinda Crescent Wheelers Hill Victoria State Australia
# entity:          Mr. Danke YU (余丹柯) : PERSON
#
#
# sample sentence: Mr. JING Zhishan (景志山) 2–2, No. 136 Wu Zhou Xin Cun Jiangbei District Chongqing, the PRC
# entity:          Mr. JING Zhishan (景志山) : PERSON
#
#
# sample sentence: UBS Securities Hong Kong Limited
# entity:          UBS Securities Hong Kong Limited : ORG
#
#
# sample sentence: Ms. Wu Xia (吳夏) Building 2 19 Minyuan South Road Haidian District Beijing, China
# entity:          Ms. Wu Xia : PERSON
#
#
# sample sentence: Mr. Lai Yat Kwong Fred (黎日光先生) 17/F, Flat G, Sung Fung Court Harbour Heights 3 Fook Yum Road Hong Kong
# entity:          Mr. Lai Yat Kwong Fred : PERSON
#
#
# sample sentence: Mr. WANG Jun (汪駿) 25E, Block 2 Scenic Heights 58A-B Conduit Road Midlevel Hong Kong
# entity:          Mr. WANG Jun : PERSON
#
#
# sample sentence: CHANG Sufang (常素芳) Room 1812, Block 415 Wangjingxiyuan Area No. 4 Chaoyang District Beijing, PRC
# entity:          CHANG Sufang : PERSON
#
#
# sample sentence: Mr. Wang Nianping (王年平) Room 501, Floor 5, Unit 2 Building 3, Court 6 Zifang Yuan Fangzhuang Fengtai District Beijing, PRC
# entity:          Mr. Wang Nianping (王年平) : PERSON
#
#
# sample sentence: Red Eagle Securities Limited (A licensed corporation to carry out type 1 (dealing in securities) regulated activities under the SFO)
# entity:          Red Eagle Securities Limited : ORG
#
#
# sample sentence: Ms. Ma Cuifang (馬翠芳). . Flat B, 15/F, Block 1 8 Amalfi Drive Discovery Bay, Lantau
# entity:          Ms. Ma Cuifang : PERSON
#
#
# sample sentence: Authorised representatives Mr. YIN Qiang
# entity:          Mr. YIN Qiang : PERSON
# entity:          Authorised representatives : TITLE
#
#
# sample sentence: Headquarters and principal place of business in the PRC No. 7 Building New Development Zone Baishixia Fuyong Street Bao'an District Shenzhen
#
#
# sample sentence: Joint Lead Managers Brilliant Norton Securities Company Limited A licensed corporation permitted to carry out type 1 (dealing in securities) and 4 (advising on regulated activities under the SFO Suite 804, 8/F Jubilee Centre 46 Gloucester Road Wanchai Hong Kong
# entity:          Joint Lead Managers : TITLE
# entity:          Brilliant Norton Securities Company Limited : ORG
#
#
# sample sentence: Frost & Sullivan (Beijing) Inc., Shanghai Branch Co. Room 1018, Tower B, No. 500 Yunjin Road Xuhui District 200232 PRC
# entity:          Frost & Sullivan (Beijing) Inc., Shanghai Branch : ORG
#
#
# sample sentence: Ho Tai Tung (何大東) Flat F, 48/F, Block 6 Island Resort Siu Sai Wan Hong Kong
# entity:          Ho Tai Tung (何大東) : PERSON
#
#
# sample sentence: Mr. Lam Keung RM 8, 39/F, Kam Hing House Tai Court Ma On Shan, New Territories Hong Kong
# entity:          Mr. Lam Keung : PERSON
#
#
# sample sentence: Mr. Wei Fu (傅唯) . 134 Ocean Drive, Singapore 098512 Singaporean
# entity:          Mr. Wei : PERSON
#
#
# sample sentence: Ms. ZHANG Xiushi (張琇石) 5/F, Tower A, Xueqing Jiachuang Building Road Haidian District Beijing, PRC
# entity:          Ms. ZHANG Xiushi (張琇石) : PERSON
#
#
# sample sentence: Audit committee Dr. Sat Chui Wan (Chairman)
# entity:          Dr. Sat Chui Wan : PERSON
# entity:          Audit committee : TITLE
#
#
# sample sentence: Dr Jørn Slot Jørgensen Mr Zhengzheng Hu (胡錚錚)
# entity:          Mr Zhengzheng Hu : PERSON
#
#
# sample sentence: Jingtian & Gongcheng Suite 45/F, K.Wah Centre 1010 Huaihai Road (M) XuHui District Shanghai PRC
# entity:          Jingtian & Gongcheng : ORG
#
#
# sample sentence: Canfield Securities Company Limited (a corporation licensed to carry out Type 1 (dealing in securities), 4 (advising on securities) and 9 (asset management) regulated activity under the SFO)
# entity:          Canfield Securities Company Limited : ORG
#
#
# sample sentence: First Shanghai Securities Limited A corporation licensed to conduct type 1 (dealing in securities), 4 (advising on securities) and 6 corporate finance) regulated activities under the SFO
# entity:          First Shanghai Securities Limited : ORG
#
#
# sample sentence: Mr. Lau Kwok Fan (劉國勳先生) Flat C605, 6/F Cheung Chi House Wah Estate Fanling, New Territories Hong Kong
# entity:          Mr. Lau Kwok Fan (劉國勳先生) : PERSON
#
#
# sample sentence: Karl-Thomson Securities Company Limited A licensed corporation to carry out type 1 (dealing in securities) and 9 (asset management) regulated activities under the SFO
# entity:          Karl-Thomson Securities Company Limited : ORG
#
#
# sample sentence: Ms. Cheung Chit San Level 54, Hopewell Centre 183 Queen's Road East Hong Kong
# entity:          Ms. Cheung Chit San : PERSON
#
#
# sample sentence: Receiving Banks Industrial and Commercial Bank of China (Asia) Limited
# entity:          Industrial and Commercial Bank of China (Asia) Limited : ORG
# entity:          Receiving Banks : TITLE
#
#
# sample sentence: BBS JP Remuneration committee Mr. Sze Irons
# entity:          Mr. Sze Irons : PERSON
# entity:          Remuneration committee : TITLE
#
#
# sample sentence: Mr. Lee Heng Wai Finance manager 34-01-10, Blok 34, Sri Sentosa Jalan Klang Lama 58000 Kuala Lumpur Malaysia
# entity:          Mr. Lee Heng : PERSON
#
#
# sample sentence: Jing Xiao (肖京) . Room 41B, Unit A, Block 1, Hongwan Garden, Beihuan Road, Futian District, Shenzhen, Guangdong, China Chinese
# entity:          Jing Xiao : PERSON
#
#
# sample sentence: Industry consultant Frost & Sullivan
# entity:          Industry consultant : TITLE
# entity:          Frost & Sullivan : ORG
#
#
# sample sentence: Mr. Matthew Ho
# entity:          Mr. Matthew Ho : PERSON
#
#
# sample sentence: Principal place of business in Hong Kong 20/F, Effectual Building 16 Hennessy Road Wanchai
#
#
# sample sentence: Auditors and reporting accountants HLB Hodgson Impey Cheng Limited
# entity:          HLB Hodgson Impey Cheng Limited : ORG
# entity:          Auditors and reporting accountants : TITLE
#
#
# sample sentence: Ms. So Shuk Yi Betty ( ACIS, ACS ) 40/F, Sunlight Tower No. 248 Queen's Road East Wanchai Hong KongDIRECTORS
# entity:          Ms. So Shuk Yi Betty : PERSON
#
#
# sample sentence: Internal control consultant RSM Consulting (Hong Kong) Limited 29/F., Lee Garden Two 28 Yun Ping Road, Causeway Bay Hong Kong
# entity:          Internal control consultant : TITLE
# entity:          RSM Consulting (Hong Kong) Limited 29/F., Lee : ORG
#
#
# sample sentence: Members of audit committee
# entity:          Members of audit committee : TITLE
#
#
# sample sentence: Safety Consultant Garron Holdings Limited
# entity:          Safety Consultant : TITLE
# entity:          Garron Holdings Limited : ORG
#
#
# sample sentence: Joint Global Coordinators CMBC Securities Company Limited 45/F, One Exchange Square, 8 Connaught Place Central, Hong Kong
# entity:          Joint Global Coordinators : TITLE
# entity:          CMBC Securities Company Limited : ORG
#
#
# sample sentence: Ng Kok Seng 48 (PTD 107123) Jln Impian Emas 67/1 Tmn Johor Bahru Malaysia
# entity:          Ng Kok Seng : PERSON
#
#
# sample sentence: Joint Bookrunners HeungKong Securities Limited A corporation licensed to carry out type 1 (dealing in securities), 2 futures contracts), 4 (advising on securities) and 9 (asset management) regulated activities under the SFO Suite 622, Ocean Centre, Harbour City, Tsim Sha Tsui Kowloon, Hong Kong
# entity:          Joint Bookrunners : TITLE
# entity:          HeungKong Securities Limited : ORG
#
#
# sample sentence: Commerce and Finance Law Offices
# entity:          Commerce and Finance Law Offices : ORG
#
#
# sample sentence: Joint Bookrunners Eastmoney International Securities Limited
# entity:          Joint Bookrunners : TITLE
# entity:          Eastmoney International Securities Limited : ORG
#
#
# sample sentence: Mr. Jiang Yulin ( ) Room 2601, Block 2A Apartment 1872, Balizhuang Beili Park Chaoyang District Beijing PRC
# entity:          Mr. Jiang Yulin : PERSON
#
#
# sample sentence: Dr. Krishnan Viswanadhan 19 Michael Lane East Hanover, NJ 07936, United States
# entity:          Dr. Krishnan : PERSON
#
#
# sample sentence: As to Hong Kong licences law: Mr. Chan Chung Barrister-at-law 10/F, Grand Building 15–18 Connaught Road Central
# entity:          Mr. Chan Chung : PERSON
#
#
# sample sentence: Legal Advisors to Our Company
# entity:          Legal Advisors to Our Company : TITLE
#
#
# sample sentence: Sole Sponsor Dakin Capital Limited (A licensed corporation carrying on Type 6 (advising corporate finance) regulated activities under the SFO)
# entity:          Dakin Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: Registered office in the Cayman Islands Cricket Square, Hutchins Drive P.O. Box 2681 Grand KY1-1111
#
#
# sample sentence: Receiving bank .
# entity:          Receiving bank : TITLE
#
#
# sample sentence: Mr. Chau Kwok Keung (鄒國強) Flat B, 9/F, Block 2 Royal Peninsula 8 Hung Lai Road Hom, Kowloon Hong Kong
# entity:          Mr. Chau Kwok Keung : PERSON
#
#
# sample sentence: Dr Jingsong Wang Suite 1103, No. 2, Lane 95 Banquan Road, Pudong New District Shanghai 200124 People's Republic of China
# entity:          Dr Jingsong Wang : PERSON
#
#
# sample sentence: Mr. Yau Sheung Hang (丘尚衡) (formerly known as Ngan Fei (邱雁飛))
# entity:          Mr. Yau Sheung Hang (丘尚衡) : PERSON
#
#
# sample sentence: Conyers Trust Company (Cayman) Limited Cricket Square Hutchins Drive P.O. Box 2681 Grand Cayman KY1-1111 Islands
# entity:          Conyers Trust Company (Cayman) Limited : ORG
#
#
# sample sentence: Principal place of business in the PRC 2 Middle Yangguang Road Zhangpu Town, Kunshan City Jiangsu Province
#
#
# sample sentence: Legal Advisers to our Company. . As Hong Kong law: Company
# entity:          Legal Advisers to our : TITLE
#
#
# sample sentence: Reporting accountants and auditor after Listing Deloitte Touche Tohmatsu
# entity:          Deloitte Touche Tohmatsu : ORG
# entity:          Reporting accountants and auditor after Listing : TITLE
#
#
# sample sentence: Hong Kong (a licensed corporation under the SFO to carry out type 1 (dealing in securities), 4 (advising on securities) and 6 corporate finance) regulated activities SFO)
#
#
# sample sentence: 85 Joint Bookrunners Citigroup Global Markets Asia Limited (in relation to the Hong Kong Public Offering) 50/F, Champion Tower 3 Garden Road Central
# entity:          Citigroup Global Markets Asia Limited : ORG
# entity:          85 Joint Bookrunners : TITLE
#
#
# sample sentence: Alliance Capital Partners Limited a licensed corporation to carry on Type 1 (dealing in securities) and 6 (advising corporate finance) regulated activities under the SFO Room 1502–1503A, Wing On House 71 Des Voeux Road Central Central, Hong Kong
# entity:          Alliance Capital Partners Limited : ORG
#
#
# sample sentence: Industry consultant All China Marketing Research Co., Ltd. 8/F, Block B, ABP Plaza Building 2, Area 1, No. 188 Western Road of South 4th Ring Fengtai District Beijing,
# entity:          Industry consultant : TITLE
#
#
# sample sentence: Certified Public Accountants, Hong Kong 42nd Floor, Central Plaza 18 Harbour Road Wanchai
#
#
# sample sentence: Audit Committee YEUNG Hiu Fu Helen (楊曉芙) (Chairman) NIU Zhongjie (牛鍾洁) HOU Min (侯珉)
# entity:          HOU Min : PERSON
# entity:          YEUNG Hiu Fu Helen : PERSON
# entity:          Audit Committee : TITLE
# entity:          NIU Zhongjie : PERSON
#
#
# sample sentence: WEN Feng (溫鋒) . Supervisor Room 1706, Building No.4 Xicui Road 5 Haidian District Beijing
# entity:          WEN Feng : PERSON
#
#
# sample sentence: Mr. Lai Chun Yu (黎振宇先生) G/F, 12 Hoi Pa Village North-East Terrace Tsuen Wan New Territories Hong Kong
# entity:          Mr. Lai Chun Yu : PERSON
#
#
# sample sentence: Legal advisers to the Sole Sponsor and Underwriters As Hong Kong law: Pinsent Masons 50th Floor Central Plaza 18 Harbour Road
# entity:          Pinsent Masons : ORG
# entity:          Legal advisers to the Sole Sponsor and Underwriters : TITLE
#
#
# sample sentence: Place of business in Hong Kong Room 2104, 21st Floor Global Trade Square 21 Wong Chuk Hang Road Hang,
#
#
# sample sentence: Property valuer Prudential Surveyors (Hong Kong) Limited
# entity:          Prudential Surveyors (Hong Kong) Limited : ORG
# entity:          Property valuer : TITLE
#
#
# sample sentence: Receiving Bank DBS (HK) Limited 11/F The Center 99 Queen's Road Central Hong Kong
# entity:          Receiving Bank : TITLE
# entity:          DBS (HK) Limited : ORG
#
#
# sample sentence: Ms. TENG Bo (滕波) 502, Unit 2, Building 8, 21 Cuiwei Road, Haidian District Beijing the PRC
# entity:          Ms. TENG Bo (滕波) : PERSON
#
#
# sample sentence: Mr. ZHU Ning (朱寧) 8-2-302 Lianxiangyuan Community Fengtai District Beijing PRC
# entity:          Mr. ZHU Ning (朱寧) 8-2-302 : PERSON
#
#
# sample sentence: 19/F & Room 2505-10, Wing On House 71 Des Voeux Road Central Hong Kong (A licensed corporation to carry out types 1, 4 and 6 regulated activities (dealing in securities, advising on securities corporate finance) under the SFO)
#
#
# sample sentence: Dr. Zhaopeng HU (胡兆鵬) Gate 3, Building 9 Dongjunzhuang Chaoyang District Beijing PRC
# entity:          Dr. Zhaopeng HU (胡兆鵬) : PERSON
#
#
# sample sentence: Sole Sponsor CMBC International Capital Limited 45/F, One Exchange Square 8 Connaught Place Central Hong Kong
# entity:          CMBC International Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: Company secretary Mr. LEE Wai Hung Garic (李偉鴻先生) (HKICPA — Non-Practising) Flat C, 40th Floor 18 Farm Road To Kwa Wan Kowloon Hong Kong
# entity:          Company secretary : TITLE
# entity:          Mr. LEE Wai Hung Garic (李偉鴻先生) (HKICPA — Non-Practising) : PERSON
#
#
# sample sentence: Ms. Gu Jianlu (顧劍璐) Room 703, Block 4 Fulinyuan Residence Community East Datun Road, Chaoyang District Beijing, the PRC
# entity:          Ms. Gu : PERSON
#
#
# sample sentence: Pierre Armand MORGON Coin d'En Haut 13 1092 Belmont-sur-Lausanne Switzerland
# entity:          Pierre Armand MORGON : PERSON
#
#
# sample sentence: Receiving banker
# entity:          Receiving banker : TITLE
#
#
# sample sentence: International Underwriters DBS Asia Capital Limited
# entity:          International Underwriters : TITLE
# entity:          DBS Asia Capital Limited : ORG
#
#
# sample sentence: Zhonglun Law Firm 33, 36, 37/F, SK Tower 6A Jianguomenwai Avenue Chaoyang District, Beijing China
# entity:          Zhonglun Law Firm : TITLE
#
#
# sample sentence: Goldman Sachs (Asia) L.L.C. 59/F, Cheung Kong Center 2 Queen's Road Central Hong
# entity:          Goldman Sachs (Asia) L.L.C. : ORG
#
#
# sample sentence: Industry Consultant
# entity:          Industry Consultant : TITLE
#
#
# sample sentence: Ms. Wong Pui Yin, Peony HKICPA Level 54, Hopewell Centre 183 Queen's Road East Hong Kong
# entity:          Ms. Wong Pui Yin, Peony : PERSON
#
#
# sample sentence: Chow Siu Lui (鄒小磊) Chan Mei Bo Mabel (陳美寶)
# entity:          Chow Siu Lui : PERSON
#
#
# sample sentence: CIS Securities Asset Management Limited
# entity:          CIS Securities Asset Management Limited : ORG
#
#
# sample sentence: Enhanced Securities Limited
# entity:          Enhanced Securities Limited : ORG
#
#
# sample sentence: Mr. LI Huagang (李華剛) No. 19, Miaoling Road Laoshan District Qingdao City Shandong PRC
# entity:          Mr. LI Huagang : PERSON
#
#
# sample sentence: Chen Gongrong (陳共榮) Room 302, Door 3, Building 3 15 Xianjia Lake Yuelu District, Changsha Hunan PRC
# entity:          Chen Gongrong (陳共榮) : PERSON
#
#
# sample sentence: Registered office in the Cayman Island Cricket Square Hutchins Drive P.O. Box 2681 Grand KY1-1111 Islands
#
#
# sample sentence: Citigroup Global Markets Asia Limited (in relation to the Hong Kong Public Offering only) 50/F, Champion Tower 3 Garden Road Central
# entity:          Citigroup Global Markets Asia Limited : ORG
#
#
# sample sentence: Hastings & Co.
# entity:          Hastings & Co. : ORG
#
#
# sample sentence: Mr. WANG Chengrui Room 1901, Greenfield Tower Concordia Plaza 1 Science Museum Road Tsim Sha Tsui East, Kowloon Hong Kong
# entity:          Mr. WANG Chengrui : PERSON
#
#
# sample sentence: Non-executive Directors (aside from our Chairperson)
# entity:          Non-executive Directors : TITLE
#
#
# sample sentence: Receiving bank DBS Bank (Hong Kong) Limited 16/F, The Center 99 Queen's Road Central Hong Kong
# entity:          Receiving bank : TITLE
# entity:          DBS Bank (Hong Kong) Limited : ORG
#
#
# sample sentence: Certified Public Accountants 35th Floor, One Pacific Place 88 Queensway Hong Kong
#
#
# sample sentence: Joint Lead Managers Seazen Resources Securities Limited Unit 4503-07, 45/F The Center 99 Queen's Road Central Hong Kong (A licensed corporation for carrying on type 1 (dealing in securities) regulated activities under the SFO)
# entity:          Joint Lead Managers : TITLE
# entity:          Seazen Resources Securities Limited : ORG
#
#
# sample sentence: Zang Weizhong (臧偉仲) Liu Yong (劉勇)
# entity:          Liu Yong : PERSON
# entity:          Zang Weizhong : PERSON
#
#
# sample sentence: Luk & Partners in Association with Morgan, Lewis Bockius
#
#
# sample sentence: Chen Li (陳立) Room 1, 43/F – 44/F Unit Block C3 Zhongwei • Yuehu Qinsheng No. 199 Zhiyin Avenue Hanyang District Wuhan, Hubei Province, PRC
# entity:          Chen Li (陳立) : PERSON
#
#
# sample sentence: Mr. REN Delin ( 任德林 )
# entity:          Mr. REN Delin : PERSON
#
#
# sample sentence: Sole Sponsor Grand Moore Capital Limited A licensed corporation under the SFO and permitted to carry out Type 1 (dealing in securities) 6 (advising on corporate finance) of regulated activities
# entity:          Grand Moore Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: 21/F, No. 8 Queen's Road Central Hong Kong As to Malaysia law David Lai & Tan
# entity:          David Lai & Tan : PERSON
#
#
# sample sentence: Property valuer Asset Appraisal Limited
# entity:          Asset Appraisal Limited : ORG
# entity:          Property valuer : TITLE
#
#
# sample sentence: Remuneration and Evaluation Committee Mr. Lin Zheying (Chairman)
# entity:          Remuneration and Evaluation Committee : TITLE
# entity:          Mr. Lin Zheying : PERSON
#
#
# sample sentence: Mr. Tian Tao Room 603, Unit 1, Building 1 Poly Beisen Residence 36 Road Qingyang District Chengdu, Sichuan Province PRC
# entity:          Mr. Tian Tao : PERSON
#
#
# sample sentence: Dr. LAM Chi Kit
# entity:          Dr. LAM Chi Kit : PERSON
#
#
# sample sentence: Joint Lead Managers CMBC Securities Company Limited
# entity:          Joint Lead Managers : TITLE
# entity:          CMBC Securities Company Limited : ORG
#
#
# sample sentence: Mr. XIAO Cifa (肖慈發) Room 202, No. 2 South Xiangyang Road, Zhongshan District, Liupanshui, Guizhou Province, PRC
# entity:          Mr. XIAO Cifa (肖慈發) : PERSON
#
#
# sample sentence: Suites 4505-06, 45/F Tower 1, Lippo Centre 89 Queensway Hong Kong (a licensed corporation under the SFO to carry out type 6 (advising on corporate finance) regulated activity SFO)
#
#
# sample sentence: Mr. Qi Mingzhi (齊明智) . Room 1001, Block A Baocui Garden No. 2045 Golden Paddy Road Luohu District Shenzhen Guangdong Province China
# entity:          Mr. Qi Mingzhi : PERSON
#
#
# sample sentence: Mr. Kung Wai Chiu Marco (孔維釗) Flat D, 11/F., Tower M9 Yoho Midtown, 9 Yuen Lung Street Long, New Territories Hong Kong
# entity:          Mr. Kung Wai Chiu Marco (孔維釗) : PERSON
#
#
# sample sentence: Block 2, No. 925 Jin Yuan Yi Road Jiading District, Shanghai, PRC (中國上海市嘉定區金園一路925號2幢)
#
#
# sample sentence: HU Xiaoling (胡曉玲) Flat 2B No. 6 Lacosta Discovery Bay Hong Kong
# entity:          HU Xiaoling (胡曉玲) : PERSON
#
#
# sample sentence: As to PRC law: King & Wood Mallesons 25th Floor, Guangzhou CTF Finance Centre No. 6 Zhujiang East Road New Town Tianhe District Guangdong 510623
# entity:          King & Wood Mallesons : ORG
#
#
# sample sentence: As to Hong Kong law: K&L Gates
# entity:          K&L Gates : ORG
#
#
# sample sentence: Mr. Shidong Jiang (蔣世東) . 15-203 Lily Garden, Vanke City Garden Shunyi District, Beijing, PRC Chinese
# entity:          Mr. Shidong Jiang (蔣世東) : PERSON
#
#
# sample sentence: Authorized representatives (for the purpose of GEM Listing Rules)
# entity:          Authorized representatives : TITLE
#
#
# sample sentence: RSM Tax Advisory (Hong Kong) Limited 29/F, Lee Garden Two 28 Yun Ping Road Causeway Bay Hong Kong
# entity:          RSM Tax Advisory (Hong Kong) Limited : ORG
#
#
# sample sentence: Li Chun Elsy (李雋) Flat C, 2/F Blessings Garden Phase II 56 Conduit Road the Mid-Levels Hong Kong
# entity:          Li Chun Elsy (李雋) : PERSON
#
#
# sample sentence: Flat D, 6/F. Chung Nam Building 163 King's Road North Point Hong Kong Audit committee Mr. Law Lap Tak (Chairman)
# entity:          Audit committee : TITLE
# entity:          Mr. Law Lap Tak : PERSON
#
#
# sample sentence: Joint Bookrunners Essence International Securities (Hong Kong) Limited
# entity:          Joint Bookrunners : TITLE
# entity:          Essence International Securities (Hong Kong) Limited : ORG
#
#
# sample sentence: Appleby 2206–19 Jardine House 1 Connaught Place Central Hong Kong
# entity:          Appleby : ORG
#
#
# sample sentence: Mr. Zhang Zhifeng (張智峰) (Chairman)
# entity:          Mr. Zhang Zhifeng (張智峰) : PERSON
#
#
# sample sentence: 18th Floor, East Tower World Financial Center 1 Dongshanhuan Zhonglu Chaoyang District Beijing, 100020 China
#
#
# sample sentence: Frost & Sullivan (Beijing) Inc., Shanghai Branch Co. Suite 1014-1018 Tower B 500 Yunjin Road PRC
# entity:          Frost & Sullivan (Beijing) Inc., Shanghai Branch Co. : ORG
#
#
# sample sentence: Room 2511 25/F Cosco Tower 183 Queen's Road Central Hong Kong I Win Securities Limited A corporation licensed under the SFO and permitted to carry out Type 1 (dealing in Securities) of regulated activities as defined
# entity:          I Win Securities Limited : ORG
#
#
# sample sentence: Strategy Committee
# entity:          Strategy Committee : TITLE
#
#
# sample sentence: Ms. Li Chengai (李成艾) 9-1101, Phase II, Ge Lan Yun Tian Residential Community Wangdong Zhonghe Sub-district Yinzhou District, Ningbo Zhejiang, PRC
# entity:          Ms. Li Chengai : PERSON
#
#
# sample sentence: Joint Bookrunners and Lead Managers (in alphabetical order)
# entity:          Joint Bookrunners and Lead Managers : TITLE
#
#
# sample sentence: Wilson Sonsini Goodrich & Rosati Suite 1509, 15/F, Jardine House 1 Connaught Place, Central Hong Kong as to PRC law:
# entity:          Wilson Sonsini Goodrich & Rosati : ORG
#
#
# sample sentence: Property valuer Jones Lang LaSalle Corporate Appraisal and Advisory Limited Level 7, One Taikoo Place
# entity:          Jones Lang LaSalle Corporate Appraisal and Advisory Limited : ORG
# entity:          Property valuer : TITLE
#
#
# sample sentence: Mr. Huang Yu (黃宇) Room 31-11, No. 17 Block 1, Hemeicheng Square Yangmuqi Road, Xinming Sub-district National Hi-Tech Zone, Ningbo Zhejiang, PRC
# entity:          Mr. Huang Yu (黃宇) : PERSON
#
#
# sample sentence: PAN Rongrong (潘蓉容) . Room 902 No. 28, Lane 388 Furongjiang Road Shanghai China
# entity:          PAN Rongrong (潘蓉容) : PERSON
#
#
# sample sentence: Mont Avenir Capital Limited Rm 3812-3813, 38/F, COSCO Tower 183 Queen's Road Central Sheung Wan Hong Kong
# entity:          Mont Avenir Capital Limited : ORG
#
#
# sample sentence: Lead Securities (HK) Limited Unit A, 23/F, The Wellington 198 Street, Central Hong Kong
# entity:          Lead Securities (HK) Limited : ORG
#
#
# sample sentence: Sole Sponsor Haitong International Capital Limited
# entity:          Haitong International Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: Mr. Tam Chun Wai Edwin (談俊緯) 13/F, Wah Yuen Building 149 Queen's Road Central Hong Kong
# entity:          Mr. Tam Chun Wai Edwin : PERSON
#
#
# sample sentence: ( Solicitor of Hong Kong ) 4404-10, 44/F One Island East 18 Westlands Road, Taikoo Place
#
#
# sample sentence: Mr. Lee Yan Fai(李恩輝) Flat B, 5/F Wing Fat Court 508 Fuk Street Cheung Sha Wan Kowloon, Hong Kong Fai
# entity:          Mr. Lee Yan Fai(李恩輝) : PERSON
#
#
# sample sentence: Ms. YU Bin (余濱) (Chairwoman)
# entity:          Ms. YU Bin (余濱) (Chairwoman) : PERSON
#
#
# sample sentence: Dr. Yu Sun Say(楊孫西) 726 Clear Water Bay Road Sai Kung New Territories Hong Kong Say
# entity:          Dr. Yu Sun Say(楊孫西) 726 : PERSON
#
#
# sample sentence: Mr. Jia Yan (賈岩) No. 1902, Building 12 Chedaogou South Lane Haidian District Beijing, PRC
# entity:          Mr. Jia Yan (賈岩) : PERSON
#
#
# sample sentence: Principal place of business in Hong Kong Room 5705, 57th Floor The Center 99 Queen's Road Central
#
#
# sample sentence: Joint Representatives, Global Coordinators, Bookrunners and Lead Managers
# entity:          Joint Representatives, Global Coordinators, Bookrunners and Lead Managers : TITLE
#
#
# sample sentence: Financial Advisor CMB International Capital Limited
# entity:          Financial Advisor : TITLE
# entity:          CMB International Capital Limited : ORG
#
#
# sample sentence: Nomination committee Mr. Chen Dewei (陳德偉) (Chairman)
# entity:          Mr. Chen Dewei : PERSON
# entity:          Nomination committee : TITLE
#
#
# sample sentence: Ms. Lau Ching Sze (劉靜詩) (HKICS, ICSA)
# entity:          Ms. Lau Ching Sze : PERSON
#
#
# sample sentence: Mr. Zhang Senquan (張森泉) Flat G, 15/F The Barion, Block 2 DD 352 Lot 385 Chianti Discovery Bay, Lantau Island Hong Kong
# entity:          Mr. Zhang Senquan : PERSON
#
#
# sample sentence: Headquarters and principal place of business in Malaysia No. 58–66, Jalan Seroja 39 Taman Johor Jaya 81100 Bahru Johor,
#
#
# sample sentence: Industrial and Commercial Bank of China (Asia) Limited 33 rd
# entity:          Industrial and Commercial Bank of China (Asia) Limited : ORG
#
#
# sample sentence: Mr. Guo Limin (郭立民) Room 1901, Building 8 Champs Elysees Garden 2 Toyota Road Futian District, Shenzhen Guangdong Province PRC
# entity:          Mr. Guo Limin (郭立民) : PERSON
#
#
# sample sentence: Reporting Accountants .
# entity:          Reporting Accountants : TITLE
#
#
# sample sentence: PO Box 1350 Clifton House 75 Fort Street Grand Cayman KY1-1108 Islands
#
#
# sample sentence: Legal Advisors to the Company .
# entity:          Legal Advisors to the Company : TITLE
#
#
# sample sentence: Tax Adviser SHINEWING and Business Advisory Limited 43/F., Lee Garden One 33 Hysan Avenue Causeway Bay Hong Kong
# entity:          Tax Adviser : TITLE
# entity:          SHINEWING and Business Advisory Limited : ORG
#
#
# sample sentence: Ms. Tu Jing (涂菁) Room 405, Unit 3 Block 19, Xinyang Riverside 250 Binjiang Road Jiujiang City Jiangxi Province PRC
# entity:          Ms. Tu Jing : PERSON
#
#
# sample sentence: Mr. Li Lap Keung (李立强) (Hong Kong Certified Public Accountant)
# entity:          Mr. Li Lap Keung : PERSON
#
#
# sample sentence: Mr. Tang Chun Ho Chandler (鄧振豪) No. 97 Yeung Uk Tsuen Au Tau Yuen Long New Territories Hong Kong
# entity:          Mr. Tang Chun Ho Chandler (鄧振豪) : PERSON
#
#
# sample sentence: As to Hong Kong law: L&C Legal LLP (in association with Jingtian & Gongcheng)
# entity:          Jingtian & Gongcheng) : ORG
# entity:          L&C Legal LLP : ORG
#
#
# sample sentence: CMB International Capital Limited, or CMBI Limited
# entity:          CMBI Limited : ORG
# entity:          CMB International Capital Limited, : ORG
#
#
# sample sentence: Mr. YIM Kai Pung (嚴繼鵬) Flat E, 11/F, Tower 2 The Harbourside 1 Austin Road West Tsim Sha Tsui, Kowloon Hong Kong
# entity:          Mr. YIM Kai Pung : PERSON
#
#
# sample sentence: Te-li Chen (陳德禮) No. 26, Lane 198, Section 1 Zhongyang North Road Beitou District Taipei City, Taiwan
# entity:          Te-li Chen : PERSON
#
#
# sample sentence: Legal Advisers to the Sole Sponsor
# entity:          Legal Advisers to the Sole Sponsor : TITLE
#
#
# sample sentence: Alameda Dr. Carlos d'Assumpcao, No. 258 Praca Kin Heng Long, 16 Andar G-H, Macau d'Assumpcao
#
#
# sample sentence: Haitong International Securities Company Limited, or Limited
# entity:          Haitong International Securities Company Limited, : ORG
#
#
# sample sentence: Mr. Dai Shunhua (戴順華先生) No. 2, Building 21 Hemu Longshan Manor Zhicheng Town, Changxing County Zhejiang Province PRC
# entity:          Mr. Dai Shunhua (戴順華先生) : PERSON
#
#
# sample sentence: Principal place of business in the PRC No. 381 Laodong East Road Tianning District, Changzhou Jiangsu Province China
#
#
# sample sentence: Mr. Leung Chun Wah (梁振華) Flat B, 7/F The Sail at Victoria 86 Road Kennedy Town Hong Kong
# entity:          Mr. Leung Chun Wah (梁振華) : PERSON
#
#
# sample sentence: Mr. Cheung Kam Fai (張錦輝) Flat/Room 04, 17/F Block Q Siu Lai House Hong Court Tuen Mun New Territories Kong
# entity:          Mr. Cheung Kam Fai (張錦輝) : PERSON
#
#
# sample sentence: Beijing Tian Yuan Law Firm
# entity:          Beijing Tian Yuan Law Firm : ORG
#
#
# sample sentence: Mr. Lee Wai Ming (李偉明) Flat A, 45/F 18 Farm Road, To Kwa Wan, Kowloon, Hong Kong
# entity:          Mr. Lee Wai Ming (李偉明) : PERSON
#
#
# sample sentence: Mr. CHEUNG Kai Cheong Willie (CPA, FCCA) 40th Floor, Sunlight Tower 248 Queen's Road East Wanchai Hong Kong
# entity:          Mr. CHEUNG Kai Cheong Willie : PERSON
#
#
# sample sentence: Company Secretary Mr. CHEUNG Kai Cheong Willie (FCPA, FCCA) Level 40, Sunlight Tower 248 Queen's Road East Wanchai Hong Kong
#
#
# sample sentence: ZHANG Shi (張實) . No. 31 Chao Shou Hutong Xi Cheng District Beijing China
# entity:          ZHANG Shi (張實) : PERSON
#
#
# sample sentence: Company secretary Mr. Lee Ka Wai (李嘉威) (Certified Public Accountant of The Hong Kong Institute Certified Accountants) Flat B, 3/F Block 3, Cronin Garden Sham Shui Po Kowloon,
# entity:          Company secretary : TITLE
# entity:          Mr. Lee Ka Wai : PERSON
#
#
# sample sentence: Mr. Hou Jianli (侯建利) No. 1, 5/F., Unit 2, Building 1 Yuan 48, Hongqi Road Weibin District, Baoji City Shaanxi Province China
# entity:          Mr. Hou Jianli (侯建利) : PERSON
#
#
# sample sentence: Receiving bank Industrial and Commercial Bank of China (Asia) Limited 33rd Floor, ICBC Tower 3 Garden Road Central Hong Kong
# entity:          Receiving bank : TITLE
# entity:          Industrial and Commercial Bank of China (Asia) Limited : ORG
#
#
# sample sentence: Mr. WEI Ming (衛明) Flat D, 25/F., Tower 1 Chatham Gate, No. 388 Road North, Kowloon Hong Kong
# entity:          Mr. WEI Ming (衛明) : PERSON
#
#
# sample sentence: Registered Office P. O. Box 309, Ugland House Grand Cayman, KY1-1104 Cayman Islands
#
#
# sample sentence: QU Daokui (曲道奎) . Apartment 18-03, No. 100-2 Dongbinhe Road, Shenhe District Shen Yang, Liaoning, China Chinese
#
#
# sample sentence: Mr. Cheung Tsun Yung, Thomas (張俊勇) 10/F, Cherry Court 12 Tai Hang Road Hong Kong
# entity:          Mr. Cheung Tsun Yung, Thomas (張俊勇) : PERSON
#
#
# sample sentence: Pulsar Capital Limited
# entity:          Pulsar Capital Limited : ORG
#
#
# sample sentence: Ms. Lin Suyan (林素燕) Room 10-1-1802 Huajiachi Apartment Intersection of Kaixuan Road and Genshan West Community Street Jianggan District Hangzhou, Zhejiang Province PRC
# entity:          Ms. Lin Suyan : PERSON
#
#
# sample sentence: Mr. Luo Weixing (駱衛星) No. 51, Zijinbei Road Xialuozhai Choucheng Yiwu City, Jinhua City Zhejiang Province PRC
# entity:          Mr. Luo Weixing : PERSON
#
#
# sample sentence: Zhang Weixin (張偉新) No. 19, Chenchongshang North Road Longjiang Town Shunde District, Foshan City Guangdong Province the PRC* (中國廣東省佛山市順德區龍江鎮 陳涌上北路19號)
# entity:          Zhang Weixin (張偉新) : PERSON
#
#
# sample sentence: As to Singapore laws: Shook Lin & Bok LLP 1 Robinson Road #18–00 AIA Tower 048542
# entity:          Shook Lin & Bok LLP : ORG
#
#
# sample sentence: ZM Lawyers
# entity:          ZM Lawyers : ORG
#
#
# sample sentence: Crédit Agricole Corporate and Investment Bank, Hong Kong branch
#
#
# sample sentence: Tak Young So (蘇德揚) 6A, Tower 7, Residence Bel Air South 38 Avenue Island Hong Kong
# entity:          Tak Young So : PERSON
#
#
# sample sentence: Yue Xiu Securities Company Limited 1003-1005 Siu On Centre 188 Lockhart Road Wan Chai Hong Kong
# entity:          Yue Xiu Securities Company Limited : ORG
#
#
# sample sentence: Company secretary Mr. Wong Tin Yu (黃天宇) (ACS, ACIS)
# entity:          Company secretary : TITLE
# entity:          Mr. Wong Tin Yu : PERSON
#
#
# sample sentence: Mr. Zhou Peng (周鵬) Room 2102, Unit 2, Building 5 1 Jinchan Huanle Garden Huaqiao City Chaoyang District Beijing PRC
# entity:          Mr. Zhou Peng (周鵬) : PERSON
#
#
# sample sentence: Sponsor Messis Capital Limited A licensed corporation to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities under the SFO
# entity:          Messis Capital Limited : ORG
# entity:          Sponsor : TITLE
#
#
# sample sentence: Standard Chartered Bank (Hong Kong) Limited 15/F Tower 388 Kwun Tong Road Hong Kong
# entity:          Standard Chartered Bank (Hong Kong) Limited : ORG
#
#
# sample sentence: Ms. Fok Po Yi (霍寶兒) ( HKICPA ) 40th Floor, Sunlight Tower 248 Queen's Road East Wanchai Hong Kong
# entity:          Ms. Fok Po Yi : PERSON
#
#
# sample sentence: Joint Bookrunners Innovax Securities Limited Unit A-C, 20/F, Neich Tower 128 Gloucester Road Wan Chai Hong Kong (A licensed corporation under the SFO to carry out Type 1 (dealing in securities) and 4 (advising on regulated activities as defined SFO)
# entity:          Joint Bookrunners : TITLE
# entity:          Innovax Securities Limited : ORG
#
#
# sample sentence: Room 2705-6, 27/F, Tower One, Lippo Centre, 89 Queensway, Hong Kong (A licensed corporation to carry out type 1 (dealing insecurities), 4 (advising on securities) and 9 (asset management) regulated activities under the SFO)
#
#
# sample sentence: Ms. Chang Wai Ha (鄭惠霞) Room 906 Ying Fuk Court 17 Wing Chuk Street Wong Tai Sin Hong Kong
# entity:          Ms. Chang Wai Ha : PERSON
#
#
# sample sentence: Huatai Financial Holdings (Hong Kong) Limited Unit 5801-05 The Center 99 Queen's Road Central Hong Kong
# entity:          Huatai Financial Holdings (Hong Kong) Limited : ORG
#
#
# sample sentence: Chiu Ricky Tong Unit A, 7/F Mountain Lodge 44 Mount Kellett Road The Peak Hong KongDIRECTORS
# entity:          Chiu Ricky Tong : PERSON
#
#
# sample sentence: * Mazars CPA Limited and LLP have been appointed as the joint auditors of our Group until conclusion first annual general meeting Company after Listing.
# entity:          Mazars CPA Limited and LLP : ORG
#
#
# sample sentence: Auditor and reporting accountants Deloitte Touche Tohmatsu Certified Public Accountants 35/F One Pacific Place 88 Queensway Hong Kong
# entity:          Auditor and reporting accountants : TITLE
# entity:          Deloitte Touche Tohmatsu : ORG
#
#
# sample sentence: Members of the nomination committee Mr. Hou Jianli (侯建利) (Chairman)
# entity:          Mr. Hou Jianli : PERSON
# entity:          Members of the nomination committee : TITLE
#
#
# sample sentence: Mr. Li Yunfeng (李雲峰) No. 194, Aomen Road, Putuo District, Shanghai, PRC Chinese
# entity:          Mr. Li Yunfeng : PERSON
#
#
# sample sentence: Mr. Lam Chi Wing (林至頴先生) Flat 3, 18/F, Block A Elizabeth House 250 Gloucester Road Causeway Bay Hong Kong
# entity:          Mr. Lam Chi Wing (林至頴先生) : PERSON
#
#
# sample sentence: SPDB International Capital Limited 33/F SPD Bank Tower One Hennessy 1 Road Hong Kong
# entity:          SPDB International Capital Limited : ORG
#
#
# sample sentence: The Properties are all located in Shekou, which exposes China Merchants Commercial REIT to the risk of a downturn economic and property market conditions Shekou. value may be adversely affected by number local conditions, such as oversupply commercial properties, performance other competing properties reduced demand for space.
#
#
# sample sentence: Head & Shoulders Securities Limited a licenced corporation to carry on type 1 (dealing in securities), 2 futures contracts) and 4 (advising securities) regulated activities for the purpose of SFO
# entity:          Head & Shoulders Securities Limited : ORG
#
#
# sample sentence: Ms. Shen Lifeng (申麗鳳女士) Room B, 23/F, The H Bonaire 68 Ap Lei Chau Main Street Hong Kong
# entity:          Ms. Shen Lifeng : PERSON
#
#
# sample sentence: Zhao Jianbo(趙劍波) Room 5-1-1002 Beiguozhichun Hangzhou City Zhejiang Province PRC Jianbo
# entity:          Zhao Jianbo(趙劍波) : PERSON
#
#
# sample sentence: Ms. Wen Yi Room 204, Zone B, Building 32 Yijing Huafu, Longyuan Longgang District, Shenzhen Guangdong Province PRC
# entity:          Ms. Wen Yi : PERSON
#
#
# sample sentence: Audit Committee . Mr. Xin Quandong (Chairman) Pei Dapeng Gao Shaoxing
# entity:          Mr. Xin : PERSON
# entity:          Audit Committee : TITLE
#
#
# sample sentence: As to PRC law (in respect of certain legal matters): Fidelity Law Firm 9/F., Erqing Mansion No.334 Hubin South Road Siming District, Xiamen City Fujian Province The
#
#
# sample sentence: Mr. Khoo Wun Fat William (丘煥法) Room E 5/F, Block 3, The Sherwood 8 Fuk Hang Tsuen Road Tuen Mun Hong Kong
# entity:          Mr. Khoo Wun Fat : PERSON
# entity:          William (丘煥法) : PERSON
#
#
# sample sentence: Addleshaw Goddard (Hong Kong) LLP
# entity:          Addleshaw Goddard (Hong Kong) LLP : ORG
#
#
# sample sentence: Auditors and reporting accountants SHINEWING (HK) CPA Limited
# entity:          Auditors and reporting accountants : TITLE
# entity:          SHINEWING (HK) CPA Limited : ORG
#
#
# sample sentence: Wenyi Huang (黃文藝) Ling Li (李玲)
# entity:          Wenyi Huang : PERSON
#
#
# sample sentence: Conyers Trust Company (Cayman) Limited Cricket Square, Hutchins Drive PO Box 2681 Grand Cayman KY1-1111 Islands
# entity:          Conyers Trust Company (Cayman) Limited : ORG
#
#
# sample sentence: Compliance Advisor
# entity:          Compliance Advisor : TITLE
#
#
# sample sentence: Mr. Zhao Leiyi (趙磊義) Room 702, Unit 2, Block 5 Saili Green City Garden Shangcheng Community Hangzhou City, Zhejiang Province China
# entity:          Mr. Zhao Leiyi (趙磊義) : PERSON
#
#
# sample sentence: Remuneration committee Mr. Koh Boon Chiao (Chairman) Jong Voon Hoo Lim Wee Pin Daniel Tay Kok Siong Wong Chee Tat
# entity:          Remuneration committee : TITLE
# entity:          Mr. Koh Boon Chiao : PERSON
#
#
# sample sentence: Ms. Zhang Jianmei (張健梅) . Room 1, Floor 1 Unit 2, Building 45 Yifeng Xincheng Huilong Shequ Zhonghe Street Sichuan, China
# entity:          Ms. Zhang Jianmei (張健梅) : PERSON
#
#
# ...
#
#
# sample sentence: 1706 One Exchange Square 8 Connaught Place Central Hong Kong
#
#
# sample sentence: CSRC APPROVAL
# entity:          CSRC APPROVAL : SKIP
#
#
# sample sentence: Certified Public Accountants Registered Interest Entity Auditor
#
#
# sample sentence: Room B, 17/F Fortune House 61 Connaught Road Central Hong Kong
#
#
# sample sentence: PARTIES INVOLVED IN THE SHARE OFFER
# entity:          PARTIES INVOLVED IN THE SHARE OFFER : SKIP
#
#
# sample sentence: Principal Place of Business in Hong Kong . 40/F Sunlight Tower 248 Queen's Road East Wanchai
#
#
# sample sentence: As an investment in a collective scheme is meant to produce returns over the long term, investors should not expect obtain short-term gains.
#
#
# sample sentence: Auditor and Reporting Accountant. Ernst & Young Certified Public Accountants 22/F CITIC Tower 1 Tim Mei Avenue Central Hong Kong
# entity:          Auditor and Reporting Accountant. : TITLE
# entity:          Ernst & Young : ORG
#
#
# sample sentence: Mr. LIN Sui (林綏) 20 Second Street Jersey City, NJ073023074 United States
# entity:          Mr. LIN Sui : PERSON
#
#
# sample sentence: 23/F Shui On Centre 6–8 Harbour Road Wan Chai Hong Kong (Solicitors of Kong)
#
#
# sample sentence: Independent non-executive Directors
# entity:          Independent non-executive Directors : TITLE
#
#
# sample sentence: Unit 4503-07, 45/F The Center 99 Queen's Road Central Hong Kong
#
#
# sample sentence: Chinese
#
#
# sample sentence: REIT Manager China Merchants Land Asset Management Co., Limited Room 2603 to 2606, 26/F Tower, Shun Tak Centre Nos. 168-200 Connaught Road Central Hong Kong
# entity:          China Merchants Land Asset Management Co., Limited : ORG
# entity:          REIT Manager : TITLE
#
#
# sample sentence: Alpha Financial Group Limited
# entity:          Alpha Financial Group Limited : ORG
#
#
# sample sentence: - 83 As to PRC law Jingtian & Gongcheng
# entity:          Jingtian & Gongcheng : ORG
#
#
# sample sentence: Market research consultant Frost & Sullivan Limited
# entity:          Market research consultant : TITLE
# entity:          Frost & Sullivan Limited : ORG
#
#
# sample sentence: CIS Securities Asset Management Limited
# entity:          CIS Securities Asset Management Limited : ORG
#
#
# sample sentence: iii. agrees with us and each of our Shareholders that the H Shares are freely transferable by holders;
#
#
# sample sentence: LANGUAGE
# entity:          LANGUAGE : ORG
#
#
# sample sentence: Aristo Securities Limited A corporation licensed by the SFC to carry on Type 1 (dealing in securities) regulated activity under SFO
# entity:          Aristo Securities Limited : ORG
#
#
# sample sentence: Barrister-at-law, Hong Kong
#
#
# sample sentence: CORPORATE INFORMATION
# entity:          CORPORATE INFORMATION : SKIP
#
#
# sample sentence: 243it [00:00, 542.09it/s]DIRECTORS
#
#
# sample sentence: ii. agrees with us, each of our Shareholders, Directors, Supervisors, managers and officers, we acting for ourselves officers Shareholders to refer all differences claims arising from Articles Association or any rights obligations conferred imposed by the PRC Company Law other relevant laws administrative regulations concerning affairs arbitration in accordance Association, reference shall be deemed authorise tribunal conduct hearings open session publish its award. Such final conclusive;
#
#
# sample sentence: Independent non-executive Directors
# entity:          Independent non-executive Directors : TITLE
#
#
# sample sentence: Headquarters in Singapore 7 Keppel Road, #3-20/21/22/23/24 Tanjong Pagar Complex Singapore, 089053 Company's website <URL> (information contained on this does not form part of prospectus)
#
#
# sample sentence: Receiving Bank(s) .
# entity:          Receiving Bank(s) : TITLE
#
#
# sample sentence: Suite 1101, 11/F Champion Tower 3 Garden Road, Central Hong Kong
#
#
# sample sentence: Headquarters and principal place of business in Malaysia No. 1–2, 2nd Floor Jalan Kajang Indah 1 Taman Sg Chua, 43000 Selengor,
#
#
# sample sentence: As to the PRC Law
#
#
# sample sentence: 40/F Sunlight Tower 248 Queen's Road East Wanchai Hong Kong
#
#
# sample sentence: Room A, 17/F Fortune House 61 Connaught Road Central Hong Kong
#
#
# sample sentence: Man Yun Wah (文潤華) (HKICS)
# entity:          Man Yun Wah : PERSON
#
#
# sample sentence: Chinese
#
#
# sample sentence: Chinese (Hong Kong)
#
#
# sample sentence: Market Consultant Knight Frank Petty Limited 4/F, Shui On Centre, 6–8 Harbour Road, Wanchai, Hong Kong
# entity:          Market Consultant Knight Frank Petty Limited : ORG
#
#
# sample sentence: Mr. Lau Wai Piu Patrick (劉偉彪) (Fellow member of the Hong Kong Institute Certified Public Accountants) Unit B, 13th Floor Winsan Tower 98 Thomson Road Wanchai,
# entity:          Mr. Lau Wai Piu Patrick : PERSON
#
#
# sample sentence: Receiving bank Bank of China (Hong Kong) Limited 1 Garden Road Hong Kong
# entity:          Receiving bank : TITLE
# entity:          Bank of China (Hong Kong) Limited : ORG
#
#
# sample sentence: Xie, Hui (謝輝) . Zhuhai Power Supply Branch of Guangdong Grid Group No. 296, Xiangzhou Cuixiang Road District, Guangdong, China
# entity:          Xie, Hui : PERSON
#
#
# sample sentence: 22/F, Prince's Building Central Hong Kong
#
#
# sample sentence: First Fidelity Capital (International) Limited
# entity:          First Fidelity Capital (International) Limited : ORG
#
#
# sample sentence: Party Name and Address
# entity:          Party Name and Address : SKIP
#
#
# sample sentence: CORPORATE INFORMATION
# entity:          CORPORATE INFORMATION : SKIP
#
#
# sample sentence: Ms. Chan Sze Man (陳詩敏女士) Flat F, 20/F, Tower 6 Harbour Green 8 Sham Mong Road Tai Kok Tsui Kowloon Hong Kong
# entity:          Ms. Chan Sze Man : PERSON
#
#
# sample sentence: Cheung, Kam Chiu (張錦釗). . Flat B, 17/F., Block 1 Peak One Shatin, New Territories Hong Kong
# entity:          Cheung, Kam Chiu : PERSON
#
#
# sample sentence: Emperor Securities Limited A corporation licensed by the SFC to carry on Type 1 (dealing in securities) and 4 (advising regulated activities under SFO
# entity:          Emperor Securities Limited : ORG
#
#
# sample sentence: Industry Consultant .
# entity:          Industry Consultant : TITLE
#
#
# sample sentence: Authorised representatives . Mr. Cheung, Kam Chiu (張錦釗) Flat B, 17/F., Block 1, Peak One Shatin, New Territories
# entity:          Mr. Cheung, Kam Chiu : PERSON
# entity:          Authorised representatives : TITLE
#
#
# sample sentence: Authorised representatives
# entity:          Authorised representatives : TITLE
#
#
# sample sentence: 37/F, ICBC Tower 3 Garden Road Hong Kong
#
#
# sample sentence: Sole Sponsor . Zhongtai International Capital Limited 19/F, Li Po Chun Chambers, 189 Des Voeux Road Central, Hong Kong (a corporation licensed to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities under the SFO)
# entity:          Zhongtai International Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: Livermore Holdings Limited A corporation licensed to carry out type 1 (dealing in securities) regulated activity under the SFO Unit 1214A, 12/F Tower II Cheung Sha Wan Plaza 833 Road Kowloon, Hong Kong
# entity:          Livermore Holdings Limited : ORG
#
#
# sample sentence: Mr. May Tai Keung Nicholas (梅大強) Unit 602, Block C Evergreen Villa 43 Stubbs Road Happy Valley Hong Kong
# entity:          Mr. May Tai Keung Nicholas (梅大強) : PERSON
#
#
# sample sentence: Independent non-executive Directors
# entity:          Independent non-executive Directors : TITLE
#
#
# sample sentence: DIRECTORS
#
#
# sample sentence: iv. authorises us to enter into a contract on his or her behalf with each of our Directors, Supervisors, managers and officers whereby such undertake observe comply their obligations Shareholders as stipulated in Articles Association. H SHARES WILL BE ELIGIBLE FOR ADMISSION INTO CCASS
#
#
# sample sentence: PARTIES INVOLVED IN THE GLOBAL OFFERING
# entity:          PARTIES INVOLVED IN THE GLOBAL OFFERING : SKIP
#
#
# sample sentence: Certified Public Accountants
#
#
# sample sentence: Chinese
#
#
# sample sentence: Li & Partners 22/F, World-Wide House, 19 Des Voeux Road Central, Hong Kong
# entity:          Li & Partners : ORG
#
#
# sample sentence: Joint Global Coordinators Citigroup Markets Asia Limited 50/F, Champion Tower, 3 Garden Road, Central, Hong Kong
# entity:          Joint Global Coordinators : TITLE
# entity:          Citigroup Markets Asia Limited : ORG
#
#
# sample sentence: 40/F, Lee Garden One 33 Hysan Avenue Causeway Bay Hong Kong
#
#
# sample sentence: Head Office and Principal Place of Business in the PRC . Unit A2 No. 700 Wanrong Road Shanghai
# entity:          Head Office and : ORG
#
#
# sample sentence: Mr. Woo Chu Fai Flat B, 43/F, Block 7 Tung Chung Crescent 2 Mei Street New Territories Hong Kong
# entity:          Mr. Woo Chu Fai : PERSON
#
#
# sample sentence: Legal advisers to our Company
# entity:          Legal advisers to our Company : TITLE
#
#
# sample sentence: Receiving bank Bank of China (Hong Kong) Limited 1 Garden Road Hong Kong
# entity:          Receiving bank : TITLE
# entity:          Bank of China (Hong Kong) Limited : ORG
#
#
# sample sentence: King & Wood Mallesons 18/F, East Tower, World Financial Centre, 1 Dongsanhuan Zhonglu, Chaoyang District, Beijing, PRC
# entity:          King & Wood Mallesons : ORG
#
#
# sample sentence: Fan, Chiu Tat Martin (范招達). . Flat B, 48/F 18 Farm Road To Kwa Wan, Kowloon Hong Kong
# entity:          Fan, Chiu Tat Martin : PERSON
#
#
# sample sentence: Mr. TONG Weiliang (童瑋亮) . No. 305, Building 4 No.37, Gupinggang Gulou District Nanjing City Jiangsu Province PRC
# entity:          Mr. TONG Weiliang : PERSON
#
#
# sample sentence: Legal adviser to the Sole Sponsor and Underwriters .
# entity:          Legal adviser to the Sole Sponsor and Underwriters : TITLE
#
#
# sample sentence: Sponsor Ample Capital Limited
# entity:          Sponsor Ample Capital Limited : ORG
#
#
# sample sentence: PARTIES INVOLVED IN THE GLOBAL OFFERING
# entity:          PARTIES INVOLVED IN THE GLOBAL OFFERING : SKIP
#
#
# sample sentence: PARTIES INVOLVED IN THE SHARE OFFER
# entity:          PARTIES INVOLVED IN THE SHARE OFFER : SKIP
#
#
# sample sentence: Frost & Sullivan International Limited
# entity:          Frost & Sullivan International Limited : ORG
#
#
# sample sentence: Non-executive Directors
# entity:          Non-executive Directors : TITLE
#
#
# sample sentence: Sole Sponsor .
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: Principal place of business in Hong Kong registered under Part 16 the Companies Ordinance .
#
#
# sample sentence: 18/F, One Pacific Place 88 Queensway Hong Kong Joint Bookrunners .
#
#
# sample sentence: 45it [00:00, 312.42it/s]DIRECTORS
#
#
# sample sentence: Please refer to the section headed "Directors, Senior Management and Staff" in prospectus for further details.
#
#
# sample sentence: Wong Kwun Ho (黃冠豪) Flat B, 20/F TST Tower 388 Un Chau Street Cheung Sha Wan, Kowloon Hong Kong
# entity:          Wong Kwun Ho : PERSON
#
#
# sample sentence: Lim Sooi Kheng Patrick (林瑞慶) . Block 3 Holland Close #22-53 Singapore 271003 Singaporean
# entity:          Lim Sooi Kheng Patrick : PERSON
#
#
# sample sentence: Li, Yanmei (李妍梅) . Flat 38E, Tower 1 Queen's Terrace Queen Street Hong Kong
#
#
# sample sentence: Yuzhou Financial Holdings Limited
# entity:          Yuzhou Financial Holdings Limited : ORG
#
#
# sample sentence: Room A, 17/F Fortune House 61 Connaught Road Central Hong Kong
#
#
# sample sentence: Sr. Dr. Leung Tony Ka Tung (梁家棟博士測量師) (Chairman)
# entity:          Sr. Dr. : PERSON
#
#
# sample sentence: The Properties are all located in Shekou, which exposes China Merchants Commercial REIT to economic and property market conditions Shekou the PRC
#
#
# sample sentence: President Securities (Hong Kong) Limited
# entity:          President Securities (Hong Kong) Limited : ORG
#
#
# sample sentence: Kho Chuan Thye Patrick (高泉泰) . 64A Andrew Road Singapore 299981 Singaporean
# entity:          Kho Chuan Thye Patrick : PERSON
#
#
# sample sentence: Dato' Ng Kwang Hua . No. 9, Jalan Bukit Mewah 9/10B Taman Fasa 10 43000 Kajang Selangor, Malaysia
# entity:          Dato' Ng Kwang Hua : PERSON
#
#
# sample sentence: Elstone Securities Limited
# entity:          Elstone Securities Limited : ORG
#
#
# sample sentence: Chinese
#
#
# sample sentence: Auditor and Reporting Accountant Deloitte Touche Tohmatsu 35/F, One Pacific Place 88 Queensway Hong Kong
# entity:          Auditor and Reporting Accountant : TITLE
# entity:          Deloitte Touche Tohmatsu : ORG
#
#
# sample sentence: Campbells Corporate Services Limited
# entity:          Campbells Corporate Services Limited : ORG
#
#
# sample sentence: Bank of China (Hong Kong) Limited 1 Garden Road Hong Kong
# entity:          Bank of China (Hong Kong) Limited : ORG
#
#
# sample sentence: 23-24/F, Emperor Group Centre 288 Hennessy Road Wanchai, Hong Kong
#
#
# sample sentence: Central China International Capital Limited A corporation licensed by the SFC to carry on Type 1 (dealing in securities) and 6 (advising corporate finance) regulated activities under SFO
# entity:          Central China International Capital Limited : ORG
#
#
# sample sentence: Chinese
#
#
# sample sentence: Unit A, 14/F. Two Chinachem Plaza 135 Des Voeux Road Central Hong Kong
#
#
# sample sentence: Ng Chee Kwong, Colin (吳志光) . Apt. Block 234A Serangoon Avenue 2 #07-143, Singapore 551234 Singaporean
# entity:          Ng Chee Kwong, Colin : PERSON
#
#
# sample sentence: Audit Committee . Mr. Xin Quandong (Chairman) Pei Dapeng Gao Shaoxing
# entity:          Mr. Xin : PERSON
# entity:          Audit Committee : TITLE
#
#
# sample sentence: 3501 The Center 99 Queen's Road Central Hong Kong
#
#
# sample sentence: Mr. Li, Zhuang (李壯) 11/F China Aerospace Centre, No.143 Hoi Bun Road, Kwun Tong Hong Kong
# entity:          Mr. : PERSON
#
#
# sample sentence: CORPORATE INFORMATION
# entity:          CORPORATE INFORMATION : SKIP
#
#
# sample sentence: Reporting accountant Deloitte Touche Tohmatsu
# entity:          Deloitte Touche Tohmatsu : ORG
# entity:          Reporting accountant : TITLE
#
#
# sample sentence: As to Cayman Islands law
#
#
# sample sentence: Company secretary Mr. Au Yeung Ming Yin Gordon (歐陽銘賢) (HKICPA) Room 16, 28/F, One Midtown 11 Hoi Shing Road, Tsuen Wan New Territories, Hong Kong
# entity:          Company secretary : TITLE
# entity:          Mr. Au Yeung Ming Yin Gordon : PERSON
#
#
# sample sentence: COMMENCEMENT OF DEALINGS IN THE SHARES
# entity:          COMMENCEMENT OF DEALINGS IN THE SHARES : SKIP
#
#
# sample sentence: Chinese
#
#
# sample sentence: Guosen Securities (HK) Capital Company Limited 42/F Two International Finance Centre, No. 8 Street, Central, Hong Kong (a corporation licensed to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities under the SFO)
# entity:          Guosen Securities (HK) Capital Company Limited : ORG
#
#
# sample sentence: Nomination committee Wong Kwun Ho (黃冠豪) (Chairman)
#
#
# sample sentence: Lee, Wing Yee Loretta (李詠怡). . Room B, Penthouse Level 1-3 Grand Deco Tower 26 Tai Hang Road Causeway Bay, Hong Kong
# entity:          Lee, Wing Yee Loretta : PERSON
#
#
# sample sentence: Sole Sponsor . Zhongtai International Capital Limited A corporation licensed to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities under the SFO 19/F., Li Po Chun Chambers 189 Des Voeux Road Central Central, Hong Kong
# entity:          Zhongtai International Capital Limited : ORG
# entity:          Sole Sponsor : TITLE
#
#
# sample sentence: SPDB International Capital Limited A corporation licensed to carry out type 1 (dealing in securities) and 6 (advising on corporate finance) regulated activities under the SFO 33/F, SPD Bank Tower One Hennessy Road Hong Kong
# entity:          SPDB International Capital Limited : ORG
#
#
# sample sentence: 1706, One Exchange Square Central Hong Kong
#
#
# sample sentence: Xu, Jili (許繼莉) . No. 89, Yong Fu Road Yuexiu District, Guangzhou China
#
#
# sample sentence: 35/F One Pacific Place 88 Queensway Hong Kong
#
#
# sample sentence: 21/F, 8 Queen's Road Central Hong Kong
#
#
# sample sentence: Mr. DAI Yunjie (戴雲傑) . Room 403, No. 68 Lane 1424, Wanhangdu Road Changning District Shanghai PRC
# entity:          Mr. DAI Yunjie : PERSON
#
#
# sample sentence: Chinese
